# %% [markdown]
# # Загрузка библиотек. Подготовка данных

# %%
import os
import csv
import stanza
from collections import Counter
import glob
import pandas as pd

# %%
# Входная папка с леммами
lemmas_folder = os.path.join("..", "data", "lemmas")

# %%
# Выходная папка для POS-статистик
output_folder = os.path.join("..", "output", "POS")
os.makedirs(output_folder, exist_ok=True)

# Получаем только файлы, начинающиеся с "cleaned"
input_files = glob.glob(os.path.join(lemmas_folder, "cleaned*.csv"))

# %% [markdown]
# # Определяем и считаем части речи

# %%
# Загружаем латинскую NLP-модель
stanza.download('la')
nlp = stanza.Pipeline(lang='la', processors='tokenize,pos')

# Обрабатываем каждый подходящий файл
for csv_path in input_files:
    filename = os.path.basename(csv_path)
    print(f"Обработка файла: {filename}")

    try:
        df = pd.read_csv(csv_path, encoding="utf-8")
    except Exception as e:
        print(f"Ошибка при чтении {filename}: {e}")
        continue

    if "lemma" not in df.columns:
        print(f"Пропущен: нет столбца 'lemma' в {filename}")
        continue

    text_data = df["lemma"].dropna().astype(str).tolist()
    text = " ".join(text_data)

    doc = nlp(text)

    pos_counter = Counter()
    for sentence in doc.sentences:
        for word in sentence.words:
            pos_counter[word.upos] += 1
            print(f"  → {word.text}: {word.upos}")

    result_df = pd.DataFrame(pos_counter.items(), columns=["Часть речи", "Количество"])

    # Формируем путь для сохранения
    output_path = os.path.join(
        output_folder,
        filename.replace(".csv", "_pos_stats.csv")
    )

    result_df.to_csv(output_path, index=False, encoding="utf-8")
    print(f"Сохранено в: {output_path}\n")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 1.91MB/s]
# 2025-05-11 18:04:03 INFO: Downloaded file to /Users/sy/stanza_resources/resources.json
# 2025-05-11 18:04:03 INFO: Downloading default packages for language: la (Latin) ...
# 2025-05-11 18:04:05 INFO: File exists: /Users/sy/stanza_resources/la/default.zip
# 2025-05-11 18:04:08 INFO: Finished downloading models and saved to /Users/sy/stanza_resources
# 2025-05-11 18:04:08 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 36.4MB/s]
# 2025-05-11 18:04:08 INFO: Downloaded file to /Users/sy/stanza_resources/resources.json
# 2025-05-11 18:04:08 WARNING: Language la package default expects mwt, which has been added
# 2025-05-11 18:04:08 INFO: Loading these models for language: la (Latin):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | ittb          |
# | mwt       | ittb          |
# | pos       | ittb_nocharlm |
# =============================
#
# 2025-05-11 18:04:08 INFO: Using device: cpu
# 2025-05-11 18:04:08 INFO: Loading: tokenize
# 2025-05-11 18:04:08 INFO: Loading: mwt
# 2025-05-11 18:04:08 INFO: Loading: pos
# 2025-05-11 18:04:12 INFO: Done loading processors!
# Обработка файла: cleaned_anonymous_angelus.predicted_лем.csv
#   → angelus: NOUN
#   → anima: NOUN
#   → Abyssus: NOUN
#   → Abies: NOUN
#   → Abortiuum: ADJ
#   → accipiter: ADV
#   → Acetum: NOUN
#   → Acies: NOUN
#   → aceruus: ADJ
#   → accubitus: VERB
#   → Acus: NOUN
#   → adolescentula: VERB
#   → Adeps: NOUN
#   → Adamas: NOUN
#   → aer: NOUN
#   → ager: NOUN
#   → agnus: NOUN
#   → Agricola: NOUN
#   → altare: NOUN
#   → alitus: ADJ
#   → Ala: NOUN
#   → alienus: ADJ
#   → altitudo: NOUN
#   → Albugus: NOUN
#   → Aloe: NOUN
#   → altilis: ADJ
#   → amicus: NOUN
#   → amicus: NOUN
#   → Amphora: NOUN
#   → Amigdalus: ADJ
#   → annulus: NOUN
#   → annus: NOUN
#   → Ancilla: NOUN
#   → anaglypha: VERB
#   → antrum: NOUN
#   → antemurale: ADJ
#   → animal: NOUN
#   → angulus: NOUN
#   → Apis: NOUN
#   → aper: NOUN
#   → aquilo: NOUN
#   → aqua: NOUN
#   → aquila: NOUN
#   → Arturus: ADJ
#   → Arista: ADJ
#   → arcus: NOUN
#   → argentum: NOUN
#   → Aries: NOUN
#   → armilla: NOUN
#   → Arena: NOUN
#   → armum: NOUN
#   → Archaarca: ADJ
#   → Arula: NOUN
#   → armo: NOUN
#   → artifex: NOUN
#   → Aruina: ADJ
#   → artus: NOUN
#   → area: NOUN
#   → arbor: NOUN
#   → Aromata: VERB
#   → areola: ADJ
#   → Aranea: ADJ
#   → armentum: NOUN
#   → Arua: NOUN
#   → aratrum: NOUN
#   → Astra: NOUN
#   → ascensus: NOUN
#   → ascensor: NOUN
#   → Asinus: ADJ
#   → Asina: NOUN
#   → Aspis: NOUN
#   → atrium: NOUN
#   → Aurora: NOUN
#   → Auster: NOUN
#   → aurum: NOUN
#   → auris: NOUN
#   → Auriga: NOUN
#   → vuis: NOUN
#   → axo: PUNCT
#   → Azyma: NOUN
#   → aduersarius: ADJ
#   → Babylon: NOUN
#   → Baculus: NOUN
#   → Balteusbalteus: ADJ
#   → barba: NOUN
#   → brachium: NOUN
#   → branchia: NOUN
#   → Bases: NOUN
#   → Basiliscus: PROPN
#   → Batus: NOUN
#   → bellum: NOUN
#   → Bechemothbeemoth: VERB
#   → Bestia: NOUN
#   → Byssus: NOUN
#   → bitumen: NOUN
#   → binarius: ADJ
#   → Botrus: NOUN
#   → Bos: NOUN
#   → buccina: NOUN
#   → Bruchus: NOUN
#   → butyrum: NOUN
#   → buxus: NOUN
#   → vadauer: VERB
#   → caligo: NOUN
#   → calor: NOUN
#   → calix: NOUN
#   → calamus: VERB
#   → calumniator: NOUN
#   → calcaneum: ADJ
#   → calculus: ADJ
#   → Callis: NOUN
#   → calceamentum: NOUN
#   → clamor: NOUN
#   → clavus: NOUN
#   → clauis: NOUN
#   → campus: NOUN
#   → camelus: NOUN
#   → Chamus: NOUN
#   → Caminus: NOUN
#   → candelabrum: NOUN
#   → candor: NOUN
#   → Canistrus: ADJ
#   → canalis: ADJ
#   → canis: NOUN
#   → caput: NOUN
#   → capillus: NOUN
#   → capitellum: NOUN
#   → castellum: NOUN
#   → capparis: ADJ
#   → caprea: ADJ
#   → capra: NOUN
#   → carcer: NOUN
#   → carus: VERB
#   → carmen: NOUN
#   → Carmelus: NOUN
#   → Cartilago: NOUN
#   → Carectus: VERB
#   → carbunculus: NOUN
#   → Caradion: NOUN
#   → cardinis: NOUN
#   → carbo: NOUN
#   → craticula: NOUN
#   → Crater: NOUN
#   → caseus: ADJ
#   → castrum: NOUN
#   → Catulus: NOUN
#   → cathedra: NOUN
#   → Catena: NOUN
#   → cataracta: VERB
#   → Cauma: ADP
#   → cauda: NOUN
#   → Cauerna: ADJ
#   → Cedrus: NOUN
#   → Cherub: NOUN
#   → coelum: NOUN
#   → cella: NOUN
#   → cellaria: ADJ
#   → caelatura: NOUN
#   → clerus: NOUN
#   → caementarius: ADV
#   → coena: NOUN
#   → cera: NOUN
#   → ceruus: ADJ
#   → ceruum: NOUN
#   → veruix: NOUN
#   → cerastes: VERB
#   → cetus: ADJ
#   → cibus: NOUN
#   → Cibaria: NOUN
#   → cicatrix: NOUN
#   → Cygnus: NOUN
#   → cilicium: NOUN
#   → Clibanus: ADJ
#   → clypeum: NOUN
#   → cymbalum: NOUN
#   → Cyphus: PUNCT
#   → cinis: NOUN
#   → Cynomyia: NOUN
#   → Cinnamomus: VERB
#   → Cincinnius: ADJ
#   → cingulum: NOUN
#   → Ciniphes: NOUN
#   → Cyprus: NOUN
#   → Cypressus: VERB
#   → circulus: NOUN
#   → Cisterna: NOUN
#   → crystallus: ADJ
#   → Cyathus: NOUN
#   → Cithara: NOUN
#   → ciuitas: NOUN
#   → ciuis: ADJ
#   → Coccus: NOUN
#   → chorus: NOUN
#   → cophinus: ADJ
#   → collum: NOUN
#   → Columba: NOUN
#   → columna: NOUN
#   → color: NOUN
#   → Coluber: NOUN
#   → Colles: NOUN
#   → Coma: NOUN
#   → compages: NOUN
#   → concentus: NOUN
#   → concubina: NOUN
#   → concubina: NOUN
#   → concupiscentia: NOUN
#   → cognitio: NOUN
#   → comedo: VERB
#   → confessio: NOUN
#   → confusio: NOUN
#   → consul: NOUN
#   → consiliarius: ADJ
#   → contentio: NOUN
#   → Conualles: ADJ
#   → Cor: NOUN
#   → corpus: NOUN
#   → coruus: NOUN
#   → corona: NOUN
#   → cornu: NOUN
#   → Cortina: NOUN
#   → cortex: NOUN
#   → crocus: NOUN
#   → Coturnix: NOUN
#   → Costa: NOUN
#   → cubitus: NOUN
#   → cubilis: ADJ
#   → culmus: NOUN
#   → culex: NOUN
#   → cultrum: NOUN
#   → currus: NOUN
#   → Crus: NOUN
#   → custos: NOUN
#   → cutis: NOUN
#   → damula: ADJ
#   → Damascus: NOUN
#   → dragma: NOUN
#   → Draco: NOUN
#   → deus: NOUN
#   → Delicia: NOUN
#   → denarius: ADJ
#   → defectus: NOUN
#   → dens: NOUN
#   → desertum: NOUN
#   → dextrum: NOUN
#   → dextrarius: ADJ
#   → diadema: NOUN
#   → dies: NOUN
#   → diluculum: NOUN
#   → digitus: ADJ
#   → dilectus: VERB
#   → diluuium: NOUN
#   → viues: NOUN
#   → diuitia: NOUN
#   → dominus: NOUN
#   → domus: NOUN
#   → dromedarius: ADJ
#   → dorsum: NOUN
#   → dormitio: NOUN
#   → dux: NOUN
#   → Ebur: NOUN
#   → ebrietas: NOUN
#   → ecclesia: NOUN
#   → Edus: NOUN
#   → Edom: PROPN
#   → Egyptus: NOUN
#   → Elata: VERB
#   → Electrus: NOUN
#   → emulatio: NOUN
#   → emunctorium: ADJ
#   → ensis: NOUN
#   → Engadi: VERB
#   → fons: NOUN
#   → eds: X
#   → equus: NOUN
#   → Erugus: NOUN
#   → eruca: NOUN
#   → Erinacii: NOUN
#   → /: PUNCT
#   → Ericius: NOUN
#   → Es: AUX
#   → Esebon: NOUN
#   → esca: NOUN
#   → esto: VERB
#   → Ethera: NOUN
#   → eternus: NOUN
#   → Ethiopia: NOUN
#   → Ethiopes: NOUN
#   → exactor: NOUN
#   → explorator: NOUN
#   → exercitus: NOUN
#   → exitus: NOUN
#   → Faretra: NOUN
#   → faber: NOUN
#   → facio: VERB
#   → fasciculus: NOUN
#   → falx: NOUN
#   → flamma: NOUN
#   → fames: NOUN
#   → Farina: NOUN
#   → frater: NOUN
#   → fragmen: PROPN
#   → Framea: NOUN
#   → Fauus: NOUN
#   → fauces: NOUN
#   → Fauilla: NOUN
#   → fel: NOUN
#   → femur: NOUN
#   → femina: NOUN
#   → feminalis: ADJ
#   → fenus: NOUN
#   → fenestra: NOUN
#   → fera: ADJ
#   → fermentum: ADJ
#   → ferrum: NOUN
#   → ferculum: NOUN
#   → frenum: ADJ
#   → festuca: NOUN
#   → fex: X
#   → fiala: NOUN
#   → ficus: NOUN
#   → filius: NOUN
#   → filia: NOUN
#   → Fimbria: NOUN
#   → firmamentum: NOUN
#   → fistula: NOUN
#   → fiscella: NOUN
#   → folium: NOUN
#   → flos: NOUN
#   → fons: NOUN
#   → foramen: NOUN
#   → forceps: NOUN
#   → fortis: ADJ
#   → fortitudo: NOUN
#   → frons: NOUN
#   → fornax: ADJ
#   → fossa: NOUN
#   → vouea: VERB
#   → finis: NOUN
#   → fuga: NOUN
#   → fulgor: NOUN
#   → fulgur: NOUN
#   → fulmen: NOUN
#   → flumen: NOUN
#   → Fluuius: ADJ
#   → fluctus: NOUN
#   → fumus: ADJ
#   → funda: NOUN
#   → fundamentum: NOUN
#   → fluenta: NOUN
#   → funis: NOUN
#   → funiculus: NOUN
#   → Fur: NOUN
#   → furor: NOUN
#   → frigus: NOUN
#   → fructus: NOUN
#   → frumentum: NOUN
#   → Galaad: NOUN
#   → Galbanus: ADJ
#   → Gallus: ADJ
#   → Gallina: NOUN
#   → Galea: NOUN
#   → glacies: NOUN
#   → gladius: NOUN
#   → glarea: NOUN
#   → gradus: NOUN
#   → gramen: NOUN
#   → granum: ADJ
#   → grando: NOUN
#   → gazophylacium: NOUN
#   → Gelus: NOUN
#   → Gena: NOUN
#   → genuum: ADJ
#   → generatio: NOUN
#   → gens: NOUN
#   → Gleba: NOUN
#   → grex: NOUN
#   → gredior: NOUN
#   → gibbus: NOUN
#   → Gigae: ADP
#   → Gomor: NOUN
#   → Gurges: NOUN
#   → gurgustium: ADJ
#   → guttur: NOUN
#   → gutta: NOUN
#   → Galilaea: PROPN
#   → Hamus: NOUN
#   → Hastilus: ADJ
#   → Hasta: NOUN
#   → habitaculum: NOUN
#   → halitus: NOUN
#   → Harundus: ADJ
#   → Harena: NOUN
#   → Herba: NOUN
#   → Hereses: ADJ
#   → hereticus: ADJ
#   → Haedus: NOUN
#   → Herodius: ADV
#   → Heremus: VERB
#   → Hermon: PROPN
#   → Hydropicus: ADJ
#   → hiems: NOUN
#   → Hyaena: ADJ
#   → hinnulus: NOUN
#   → hinnitus: NOUN
#   → Hirundus: NOUN
#   → hircus: NOUN
#   → homo: NOUN
#   → horribilis: ADJ
#   → humus: NOUN
#   → humilitas: NOUN
#   → humor: NOUN
#   → humerulus: ADJ
#   → humerus: NOUN
#   → holocaustum: VERB
#   → Herodes: PROPN
#   → hodie: ADV
#   → /: PUNCT
#   → gigno: NOUN
#   → facio: VERB
#   → Iacinctus: VERB
#   → iaspis: NOUN
#   → ianua: NOUN
#   → Ibices: ADJ
#   → Idumaea: ADJ
#   → Ierusalem: ADJ
#   → ignis: NOUN
#   → imago: NOUN
#   → impetigo: NOUN
#   → impius: ADJ
#   → imber: NOUN
#   → incus: NOUN
#   → India: NOUN
#   → inaura: ADJ
#   → infans: ADJ
#   → infernus: NOUN
#   → insula: NOUN
#   → intestino: ADJ
#   → institor: NOUN
#   → Iordanis: NOUN
#   → iuncus: ADJ
#   → Iuniperus: NOUN
#   → iugum: NOUN
#   → iustitia: NOUN
#   → iudex: NOUN
#   → iudicium: NOUN
#   → iumentum: NOUN
#   → Iuuenes: ADJ
#   → Iuuentus: NOUN
#   → ira: NOUN
#   → deus: NOUN
#   → iniquitas: NOUN
#   → kalenda: VERB
#   → labium: NOUN
#   → labrum: NOUN
#   → Labrusca: NOUN
#   → lac: NOUN
#   → lacus: NOUN
#   → Lactuca: NOUN
#   → lacerta: NOUN
#   → laguncula: NOUN
#   → Lagena: NOUN
#   → lamina: NOUN
#   → Lamia: ADJ
#   → Lana: NOUN
#   → lancea: NOUN
#   → lapis: NOUN
#   → Lampas: NOUN
#   → Laqueus: NOUN
#   → laquearium: ADJ
#   → Later: PUNCT
#   → latus: NOUN
#   → latitudo: NOUN
#   → Latomus: VERB
#   → latros: NOUN
#   → Leo: NOUN
#   → Leaena: NOUN
#   → lectus: ADJ
#   → lectulus: ADJ
#   → lex: NOUN
#   → legislator: NOUN
#   → legatus: VERB
#   → legatio: NOUN
#   → Lepus: NOUN
#   → Lepra: NOUN
#   → leprosus: ADJ
#   → leuo: NOUN
#   → Leuiathan: VERB
#   → Libanus: ADJ
#   → lingua: NOUN
#   → lignum: NOUN
#   → lignum: NOUN
#   → Lilius: NOUN
#   → limen: NOUN
#   → linum: NOUN
#   → linea: NOUN
#   → Littus: NOUN
#   → Lippus: NOUN
#   → liber: ADJ
#   → locus: NOUN
#   → locusta: NOUN
#   → loculus: ADJ
#   → longitudo: NOUN
#   → lus: X
#   → lux: NOUN
#   → Lucifer: PROPN
#   → Lucerna: NOUN
#   → lumen: NOUN
#   → lumbus: NOUN
#   → lumbo: NOUN
#   → luna: NOUN
#   → lupus: NOUN
#   → lutum: NOUN
#   → Luter: NOUN
#   → Maceria: NOUN
#   → macula: NOUN
#   → malum: NOUN
#   → Punicus: ADJ
#   → malogranata: VERB
#   → malus: NOUN
#   → Mamma: NOUN
#   → mano: NOUN
#   → matutinum: NOUN
#   → manus: NOUN
#   → manna: NOUN
#   → Manipulus: NOUN
#   → Mandragora: NOUN
#   → Margus: NOUN
#   → mare: NOUN
#   → Marmor: NOUN
#   → Margarita: VERB
#   → masculus: NOUN
#   → mater: NOUN
#   → malleus: NOUN
#   → Maxilla: NOUN
#   → Medulla: NOUN
#   → mel: NOUN
#   → membrum: NOUN
#   → mensis: NOUN
#   → mensa: NOUN
#   → moenium: NOUN
#   → meridies: NOUN
#   → mercenarius: ADJ
#   → meretrix: NOUN
#   → messis: NOUN
#   → messor: NOUN
#   → Mica: NOUN
#   → miles: NOUN
#   → militia: NOUN
#   → miluus: NOUN
#   → Myrrha: NOUN
#   → Myrtus: NOUN
#   → Myrica: NOUN
#   → Mytra: PUNCT
#   → Moab: PROPN
#   → modius: NOUN
#   → mola: NOUN
#   → Monilia: NOUN
#   → mons: NOUN
#   → mors: NOUN
#   → Morus: NOUN
#   → Mortariolum: ADJ
#   → mons: NOUN
#   → mulier: NOUN
#   → mulus: NOUN
#   → munitio: NOUN
#   → murus: NOUN
#   → murenula: ADJ
#   → musca: NOUN
#   → mustus: VERB
#   → Mustela: NOUN
#   → naris: ADJ
#   → Nardus: NOUN
#   → nasus: NOUN
#   → Nauis: NOUN
#   → nauicula: ADJ
#   → nebula: NOUN
#   → Neruus: ADJ
#   → nemus: NOUN
#   → nycticorax: ADJ
#   → nidus: NOUN
#   → nidulus: NOUN
#   → nigredo: NOUN
#   → nitrum: NOUN
#   → nix: NOUN
#   → noctuus: NOUN
#   → nouaculum: NOUN
#   → nox: NOUN
#   → nubes: NOUN
#   → nuptia: ADJ
#   → nurus: NOUN
#   → nuces: NOUN
#   → Obryzus: VERB
#   → obstetrix: ADJ
#   → oculus: NOUN
#   → Occidens: VERB
#   → odor: NOUN
#   → oliua: ADJ
#   → oleum: NOUN
#   → olla: NOUN
#   → onocentaurus: VERB
#   → Onager: NOUN
#   → Onycha: ADP
#   → optimas: ADJ
#   → orbis: NOUN
#   → Ordeus: VERB
#   → organum: NOUN
#   → oriens: VERB
#   → Occidens: VERB
#   → orio: NOUN
#   → ortus: NOUN
#   → os: NOUN
#   → os: NOUN
#   → os: NOUN
#   → os: NOUN
#   → osculum: NOUN
#   → ostium: NOUN
#   → ovum: NOUN
#   → ouis: NOUN
#   → Ouile: ADJ
#   → pax: NOUN
#   → pacificus: ADJ
#   → palma: NOUN
#   → palmes: NOUN
#   → pallium: NOUN
#   → palpebra: NOUN
#   → palea: NOUN
#   → palus: NOUN
#   → paliurus: ADJ
#   → plaga: NOUN
#   → planta: NOUN
#   → Platanus: ADJ
#   → platea: NOUN
#   → panis: NOUN
#   → Pannus: NOUN
#   → Papyrus: NOUN
#   → Papirius: PROPN
#   → paradisus: NOUN
#   → paries: NOUN
#   → Pardus: NOUN
#   → pastus: NOUN
#   → Passer: NOUN
#   → pater: NOUN
#   → pauimentum: NOUN
#   → paxillus: ADJ
#   → pectus: NOUN
#   → pectusculum: NOUN
#   → pecus: NOUN
#   → peccatum: NOUN
#   → pes: NOUN
#   → pellis: NOUN
#   → pellicanus: ADJ
#   → pleo: VERB
#   → Penna: NOUN
#   → pennula: VERB
#   → Pepones: NOUN
#   → pero: VERB
#   → Peregrinus: ADJ
#   → perdix: NOUN
#   → praeda: NOUN
#   → praesepe: NOUN
#   → praedo: NOUN
#   → pessulum: ADJ
#   → petra: NOUN
#   → pictura: NOUN
#   → Pilius: NOUN
#   → pilosus: ADJ
#   → Pleiades: NOUN
#   → Pinus: NOUN
#   → primogenitum: ADJ
#   → princeps: NOUN
#   → piscina: NOUN
#   → piscis: NOUN
#   → piscator: NOUN
#   → pomum: NOUN
#   → pontifex: NOUN
#   → porta: NOUN
#   → porticus: NOUN
#   → Porrus: NOUN
#   → Porcius: PROPN
#   → procurator: NOUN
#   → propitiatorium: ADJ
#   → propugnator: NOUN
#   → propugnaculum: NOUN
#   → postis: NOUN
#   → potens: VERB
#   → puer: NOUN
#   → Pullus: ADJ
#   → puluis: NOUN
#   → puluillus: ADJ
#   → plumbum: NOUN
#   → vluuia: NOUN
#   → puncgo: VERB
#   → Pupilla: NOUN
#   → pupillus: NOUN
#   → purpura: NOUN
#   → Pruina: NOUN
#   → Pruna: NOUN
#   → Puteumputeus: ADJ
#   → quadriga: NOUN
#   → quercus: NOUN
#   → quadrans: VERB
#   → radix: NOUN
#   → ramus: ADJ
#   → Rhamnus: NOUN
#   → rana: NOUN
#   → rapina: NOUN
#   → rationalis: ADJ
#   → rex: NOUN
#   → Regina: NOUN
#   → regnum: NOUN
#   → regula: NOUN
#   → Regulus: NOUN
#   → reclinatorium: ADJ
#   → renis: NOUN
#   → reptilis: ADJ
#   → reto: VERB
#   → resticula: ADJ
#   → retributio: NOUN
#   → rinoceros: NOUN
#   → risus: NOUN
#   → Riui: NOUN
#   → riuulus: NOUN
#   → Ros: NOUN
#   → rosa: NOUN
#   → rota: NOUN
#   → rubor: NOUN
#   → rubus: NOUN
#   → rubigo: NOUN
#   → rugitus: NOUN
#   → ruga: NOUN
#   → rupis: NOUN
#   → sabbatum: NOUN
#   → sacerdos: NOUN
#   → Saccus: NOUN
#   → sacculus: NOUN
#   → scala: ADJ
#   → scapula: NOUN
#   → Scarabaeus: ADJ
#   → Scabies: NOUN
#   → Scabellus: NOUN
#   → saga: NOUN
#   → sagittarius: ADJ
#   → sagitta: NOUN
#   → sagena: NOUN
#   → Sapphirus: NOUN
#   → sal: NOUN
#   → salsugo: NOUN
#   → saliunca: ADJ
#   → salix: NOUN
#   → Salterium: ADJ
#   → sanguis: NOUN
#   → sanies: NOUN
#   → squama: NOUN
#   → sartago: NOUN
#   → Sardonychus: ADJ
#   → stabulum: NOUN
#   → Stactes: ADJ
#   → Stannumstagnus: NOUN
#   → stamen: NOUN
#   → statera: NOUN
#   → statura: NOUN
#   → stgo: VERB
#   → saxum: NOUN
#   → securis: NOUN
#   → sedes: NOUN
#   → Segor: NOUN
#   → semen: NOUN
#   → semita: NOUN
#   → senex: ADJ
#   → senectus: NOUN
#   → senator: NOUN
#   → seo: NOUN
#   → sepis: NOUN
#   → sepulcrum: NOUN
#   → spelunca: NOUN
#   → Sphaerulaesperule: ADJ
#   → speculum: NOUN
#   → speculator: NOUN
#   → specus: NOUN
#   → species: NOUN
#   → seruus: NOUN
#   → serpens: VERB
#   → serra: NOUN
#   → Stellius: ADJ
#   → stella: NOUN
#   → sterilis: ADJ
#   → stercus: NOUN
#   → sterquilinium: ADJ
#   → sternutatio: NOUN
#   → sibilus: ADJ
#   → Sycomorus: NOUN
#   → Siclus: NOUN
#   → signaculum: NOUN
#   → vilua: VERB
#   → siliqua: ADJ
#   → silex: NOUN
#   → similago: ADJ
#   → symphonia: NOUN
#   → Sindus: NOUN
#   → sinus: NOUN
#   → sinistra: ADJ
#   → scintilla: NOUN
#   → spica: NOUN
#   → spina: NOUN
#   → spiritus: NOUN
#   → Sirpus: NOUN
#   → sirena: ADJ
#   → sitis: NOUN
#   → stipula: VERB
#   → Stillio: NOUN
#   → Stilus: NOUN
#   → Stilla: NOUN
#   → stillicidia: NOUN
#   → Socrus: NOUN
#   → Sol: NOUN
#   → solium: NOUN
#   → solitudo: NOUN
#   → somnus: NOUN
#   → sonus: NOUN
#   → Spolia: NOUN
#   → sporta: NOUN
#   → stola: NOUN
#   → Scorpius: NOUN
#   → soror: NOUN
#   → Subula: VERB
#   → scutum: NOUN
#   → sculptura: NOUN
#   → sudis: NOUN
#   → sulphur: NOUN
#   → sulcus: NOUN
#   → Sunamitis: NOUN
#   → superhumerale: ADJ
#   → superbus: ADJ
#   → superbia: NOUN
#   → sus: NOUN
#   → Struthius: ADJ
#   → tabernaculum: NOUN
#   → tabula: NOUN
#   → talentum: NOUN
#   → Trabs: NOUN
#   → Thalamus: VERB
#   → Taurus: NOUN
#   → tectum: NOUN
#   → Tela: NOUN
#   → templum: NOUN
#   → tentatio: NOUN
#   → tentorium: NOUN
#   → terra: NOUN
#   → thesaurus: NOUN
#   → Testa: NOUN
#   → Tigris: NOUN
#   → tignum: NOUN
#   → Thymiama: NOUN
#   → Tiara: NOUN
#   → tympanum: NOUN
#   → tinea: VERB
#   → tintinnabulum: ADJ
#   → tinctura: NOUN
#   → tribulus: NOUN
#   → triticum: NOUN
#   → tonitrus: NOUN
#   → Thorax: ADJ
#   → torrens: VERB
#   → topazion: NOUN
#   → Tornatornalis: ADJ
#   → torcular: NOUN
#   → thronus: ADJ
#   → Tuba: NOUN
#   → tunica: NOUN
#   → turtur: VERB
#   → turris: NOUN
#   → thuribulum: NOUN
#   → truncus: NOUN
#   → Trulla: NOUN
#   → thusthuribulum: ADJ
#   → poenitentia: NOUN
#   → ?: PUNCT
#   → uah: VERB
#   → Uacca: NOUN
#   → uagen: X
#   → uallis: NOUN
#   → uapor: NOUN
#   → uo: X
#   → Uectis: X
#   → Uelus: NOUN
#   → Uellus: NOUN
#   → Uena: NOUN
#   → Uenenus: NOUN
#   → uentus: NOUN
#   → uenter: NOUN
#   → uentilabrum: ADJ
#   → uepres: NOUN
#   → uermis: ADJ
#   → uer: NOUN
#   → uertex: NOUN
#   → uestimentum: NOUN
#   → uestis: NOUN
#   → uestigium: NOUN
#   → uestibulum: ADJ
#   → uesper: NOUN
#   → uesperus: ADJ
#   → uespera: ADJ
#   → uespertilio: NOUN
#   → Uesica: ADJ
#   → uia: NOUN
#   → uiator: NOUN
#   → Uici: VERB
#   → vidua: NOUN
#   → Uigiles: ADJ
#   → Uilla: NOUN
#   → uinum: NOUN
#   → uinea: NOUN
#   → uinculum: NOUN
#   → uipera: VERB
#   → Uir: NOUN
#   → Uirgus: NOUN
#   → Uirga: NOUN
#   → Uirgula: ADJ
#   → Uirentia: NOUN
#   → uirtus: NOUN
#   → uisio: NOUN
#   → uiscerum: NOUN
#   → uitis: NOUN
#   → uita: NOUN
#   → uitta: NOUN
#   → Uitulus: ADJ
#   → Uitula: NOUN
#   → uitrum: NOUN
#   → uolucer: NOUN
#   → Uomer: NOUN
#   → uox: NOUN
#   → uultus: NOUN
#   → Uultur: VERB
#   → uulnus: NOUN
#   → uulpesuulpis: ADJ
#   → uberus: VERB
#   → ulcus: NOUN
#   → ulula: NOUN
#   → ulmus: NOUN
#   → Umbilicus: ADJ
#   → umbra: NOUN
#   → ungula: NOUN
#   → unicus: ADJ
#   → unguentum: NOUN
#   → Urna: NOUN
#   → Urtica: NOUN
#   → Ursus: NOUN
#   → uterus: NOUN
#   → uter: PRON
#   → Uasuua: ADJ
#   → uxor: NOUN
#   → x: NUM
#   → P: NUM
#   → Schristus: NOUN
#   → Yades: VERB
#   → Ydria: NOUN
#   → Ydropicus: ADJ
#   → Ysopus: VERB
#   → zelus: NOUN
#   → Zizania: NOUN
#   → Zona: NOUN
# Сохранено в: ../output/POS/cleaned_anonymous_angelus.predicted_лем_pos_stats.csv
#
# Обработка файла: cleaned_alanus_de_insula_dist_summa.predicted_лем.csv
#   → anima: NOUN
#   → animale: ADJ
#   → animal: NOUN
#   → aqua: NOUN
#   → Abyssus: NOUN
#   → vuis: NOUN
#   → aquila: NOUN
#   → accipiter: ADV
#   → Ala: NOUN
#   → aer: NOUN
#   → Acus: NOUN
#   → aceruus: ADJ
#   → ager: NOUN
#   → aquilo: NOUN
#   → amicus: NOUN
#   → amaritudo: NOUN
#   → Asinus: ADJ
#   → Absintium: ADJ
#   → altare: ADJ
#   → Adeps: NOUN
#   → atrium: NOUN
#   → Aries: NOUN
#   → area: NOUN
#   → Aroma: NOUN
#   → Arundus: NOUN
#   → arcus: NOUN
#   → Aruina: ADJ
#   → aratrum: NOUN
#   → Acetum: VERB
#   → Aculeus: ADJ
#   → apes: NOUN
#   → Hasta: NOUN
#   → Hamus: NOUN
#   → aura: NOUN
#   → Aurora: NOUN
#   → auris: NOUN
#   → Auster: NOUN
#   → aurum: NOUN
#   → Aurichalcus: ADJ
#   → accubitus: VERB
#   → Acies: NOUN
#   → Arena: NOUN
#   → angelus: NOUN
#   → agnus: NOUN
#   → Azyma: ADJ
#   → altus: ADJ
#   → altitudo: NOUN
#   → amor: NOUN
#   → aula: NOUN
#   → argentum: NOUN
#   → arbor: NOUN
#   → auditus: NOUN
#   → annus: NOUN
#   → anulusannulus: ADJ
#   → amygdalus: NOUN
#   → Arista: ADJ
#   → Adamas: NOUN
#   → amethystus: VERB
#   → antrum: NOUN
#   → arcturus: NOUN
#   → antemurale: ADJ
#   → Abies: NOUN
#   → Aspis: NOUN
#   → armum: NOUN
#   → Agricola: ADJ
#   → agricultura: NOUN
#   → angulus: NOUN
#   → altilis: ADJ
#   → ambitio: NOUN
#   → ambitus: NOUN
#   → adolescentula: VERB
#   → artifex: NOUN
#   → areola: ADJ
#   → Aloes: NOUN
#   → Axella: ADJ
#   → Arca: NOUN
#   → Aranea: ADJ
#   → ago: VERB
#   → ascendo: VERB
#   → audio: VERB
#   → aro: NOUN
#   → adoro: VERB
#   → assumo: VERB
#   → accedo: VERB
#   → accipio: VERB
#   → abeo: VERB
#   → habeo: VERB
#   → habito: VERB
#   → ambulo: VERB
#   → asto: VERB
#   → aperio: VERB
#   → aresco: NOUN
#   → Adesse: VERB
#   → vel: CCONJ
#   → aduersus: ADP
#   → absque: ADP
#   → alias: DET
#   → amen: ADV
#   → aus: NOUN
#   → baptismus: NOUN
#   → Basae: NOUN
#   → Baculus: NOUN
#   → Barbarus: NOUN
#   → barba: NOUN
#   → brachium: NOUN
#   → Babylon: NOUN
#   → Basiliscus: ADJ
#   → beatus: ADJ
#   → bellum: NOUN
#   → Bestia: NOUN
#   → Berillus: ADJ
#   → binus: ADJ
#   → Byssus: NOUN
#   → Biothanatus: VERB
#   → Biblus: NOUN
#   → Bilibris: NOUN
#   → bilis: NOUN
#   → bonus: ADJ
#   → Bos: NOUN
#   → Botrus: NOUN
#   → buccina: NOUN
#   → buxus: NOUN
#   → butyrum: NOUN
#   → Bruchus: NOUN
#   → benedico: VERB
#   → bibo: VERB
#   → carus: VERB
#   → caput: NOUN
#   → Cataracte: ADV
#   → Cassia: PROPN
#   → carmen: NOUN
#   → cataclysmus: NOUN
#   → canis: NOUN
#   → calix: NOUN
#   → Carbo: ADJ
#   → caligo: NOUN
#   → caupo: NOUN
#   → vadauer: VERB
#   → candor: NOUN
#   → capparis: ADJ
#   → Calcedonius: ADJ
#   → catena: NOUN
#   → Callis: NOUN
#   → Caminus: NOUN
#   → campus: NOUN
#   → capillus: ADJ
#   → Calcaneus: ADJ
#   → Cauerna: NOUN
#   → Cauma: ADP
#   → cauda: NOUN
#   → Chamus: ADP
#   → castrum: NOUN
#   → camelus: NOUN
#   → crassitudo: NOUN
#   → calamus: VERB
#   → clauis: NOUN
#   → calor: NOUN
#   → character: ADJ
#   → clamor: NOUN
#   → Catulus: NOUN
#   → canticum: NOUN
#   → calceamentum: NOUN
#   → Cartilago: NOUN
#   → cardo: NOUN
#   → charitas: NOUN
#   → claritas: NOUN
#   → carcer: NOUN
#   → cancellus: ADJ
#   → clauus: VERB
#   → cathedra: NOUN
#   → candelabrum: NOUN
#   → casus: NOUN
#   → calculus: ADJ
#   → caprea: ADJ
#   → Carmelus: NOUN
#   → Canalis: ADJ
#   → Crater: NOUN
#   → celum: ADJ
#   → Cherubin: NOUN
#   → veruix: NOUN
#   → ceruus: ADJ
#   → clerus: NOUN
#   → cena: NOUN
#   → creatura: NOUN
#   → cera: NOUN
#   → cecus: ADJ
#   → Cedrus: NOUN
#   → Chrysoprasus: ADJ
#   → Chrysolithus: NOUN
#   → Clypeus: ADJ
#   → crystallus: ADJ
#   → Scirpus: NOUN
#   → cilicium: ADJ
#   → Cinnamomus: VERB
#   → cibus: NOUN
#   → ciuitas: NOUN
#   → cinis: NOUN
#   → cingulum: NOUN
#   → Christus: ADJ
#   → circuitus: NOUN
#   → circulus: NOUN
#   → Clibanus: ADJ
#   → scyphus: NOUN
#   → Cithara: NOUN
#   → Cincinnus: ADJ
#   → cymbalum: ADJ
#   → cornu: NOUN
#   → corona: NOUN
#   → Cor: NOUN
#   → Columba: NOUN
#   → columna: NOUN
#   → corruptio: NOUN
#   → corpus: NOUN
#   → Coluber: NOUN
#   → contritio: NOUN
#   → confessio: NOUN
#   → chorus: NOUN
#   → chorda: NOUN
#   → collum: NOUN
#   → collis: NOUN
#   → coruus: NOUN
#   → compes: NOUN
#   → cophinus: NOUN
#   → Cortina: NOUN
#   → concubina: NOUN
#   → cortex: NOUN
#   → consul: NOUN
#   → Costa: NOUN
#   → como: CCONJ
#   → crocus: NOUN
#   → consilium: NOUN
#   → currus: NOUN
#   → Cuneus: NOUN
#   → cursus: NOUN
#   → cutis: NOUN
#   → cubilis: ADJ
#   → culmus: NOUN
#   → custos: NOUN
#   → Crus: NOUN
#   → crux: NOUN
#   → capeo: ADJ
#   → cado: NOUN
#   → clamo: VERB
#   → cano: NOUN
#   → creo: VERB
#   → credo: VERB
#   → cedo: VERB
#   → censeo: VERB
#   → circuio: NOUN
#   → cribro: NOUN
#   → cibo: NOUN
#   → colligo: VERB
#   → Colare: VERB
#   → colo: VERB
#   → confiteror: VERB
#   → contingo: VERB
#   → confero: VERB
#   → considero: VERB
#   → concupiscor: VERB
#   → confundo: VERB
#   → cognosco: VERB
#   → conuenio: NOUN
#   → comedo: VERB
#   → contero: NOUN
#   → consto: PUNCT
#   → curro: VERB
#   → curo: VERB
#   → coro: NOUN
#   → con: CCONJ
#   → contra: ADP
#   → cras: NOUN
#   → cito: NOUN
#   → Dauid: PROPN
#   → do: VERB
#   → dragma: NOUN
#   → Draco: NOUN
#   → deus: NOUN
#   → dextera: ADJ
#   → desertum: NOUN
#   → dens: NOUN
#   → decor: NOUN
#   → demonium: NOUN
#   → delictum: NOUN
#   → denarius: ADJ
#   → dies: NOUN
#   → diadema: NOUN
#   → diluuium: ADJ
#   → diluculum: NOUN
#   → viuitie: VERB
#   → diabolus: PROPN
#   → dio: NUM
#   → viues: NOUN
#   → Diplois: NOUN
#   → digitus: NOUN
#   → domus: NOUN
#   → donum: NOUN
#   → dorsum: NOUN
#   → dromedarius: ADJ
#   → doma: VERB
#   → /: PUNCT
#   → domas: VERB
#   → dux: NOUN
#   → durus: ADJ
#   → dulcis: NOUN
#   → dulia: NOUN
#   → do: VERB
#   → damno: NOUN
#   → depono: VERB
#   → deduco: VERB
#   → descendo: VERB
#   → deficio: VERB
#   → deleo: VERB
#   → dedico: VERB
#   → describo: NOUN
#   → dico: VERB
#   → diligo: VERB
#   → dimitto: VERB
#   → dispergo: NOUN
#   → dissipo: NOUN
#   → dormio: VERB
#   → dolao: VERB
#   → donec: SCONJ
#   → ecclesia: NOUN
#   → euus: NOUN
#   → Etas: NOUN
#   → esto: AUX
#   → estus: NOUN
#   → hereditas: NOUN
#   → elementum: NOUN
#   → Es: AUX
#   → Egyptus: VERB
#   → Herba: NOUN
#   → energia: NOUN
#   → ethiops: PUNCT
#   → Hedus: NOUN
#   → esca: NOUN
#   → emissarius: ADJ
#   → equus: NOUN
#   → Epiphania: NOUN
#   → eternus: ADJ
#   → Ebur: NOUN
#   → Herodius: ADV
#   → Ericius: NOUN
#   → Erugus: NOUN
#   → eruca: NOUN
#   → exeo: VERB
#   → egredior: NOUN
#   → exsurgo: NOUN
#   → excludo: VERB
#   → expono: VERB
#   → emitto: VERB
#   → effundo: VERB
#   → expello: VERB
#   → excuto: ADP
#   → euello: NOUN
#   → emulor: NOUN
#   → extra: ADP
#   → ecce: PART
#   → euge: VERB
#   → flamma: NOUN
#   → Fauilla: ADJ
#   → facula: NOUN
#   → Fauus: NOUN
#   → facio: VERB
#   → fames: NOUN
#   → facio: VERB
#   → frater: NOUN
#   → flamen: NOUN
#   → falx: NOUN
#   → flatus: NOUN
#   → Farina: NOUN
#   → fasciculus: ADJ
#   → Pharetra: NOUN
#   → fatum: NOUN
#   → fabula: NOUN
#   → fama: NOUN
#   → familia: NOUN
#   → fragmen: PROPN
#   → Framea: NOUN
#   → fauces: NOUN
#   → fermentum: ADJ
#   → ferculum: NOUN
#   → fel: NOUN
#   → feta: VERB
#   → fenestra: NOUN
#   → ferrum: NOUN
#   → fenus: NOUN
#   → Fescennie: VERB
#   → fex: X
#   → femur: NOUN
#   → ferramentum: NOUN
#   → fera: ADJ
#   → frenum: ADJ
#   → fides: NOUN
#   → filius: NOUN
#   → ficus: NOUN
#   → Phiala: ADJ
#   → Fimbria: NOUN
#   → figulus: NOUN
#   → filus: ADJ
#   → fidelis: ADJ
#   → figura: NOUN
#   → finis: NOUN
#   → fistula: NOUN
#   → forma: NOUN
#   → flos: NOUN
#   → fons: NOUN
#   → folium: NOUN
#   → fornax: NOUN
#   → frons: NOUN
#   → vouea: VERB
#   → fossa: NOUN
#   → fumus: NOUN
#   → Fluuius: ADJ
#   → fulgurfulgurum: NOUN
#   → fulmen: NOUN
#   → flumen: NOUN
#   → fluctus: NOUN
#   → Fur: NOUN
#   → frumentum: NOUN
#   → furor: NOUN
#   → fructus: NOUN
#   → funis: NOUN
#   → facio: VERB
#   → fascino: NOUN
#   → frango: VERB
#   → fremeo: NOUN
#   → feteo: VERB
#   → fero: VERB
#   → frendo: VERB
#   → fingo: VERB
#   → foueo: VERB
#   → fodio: NOUN
#   → floreo: ADJ
#   → formo: NOUN
#   → fornicarus: ADJ
#   → fou: X
#   → fugio: VERB
#   → forsitan: ADP
#   → gratia: NOUN
#   → vrauis: VERB
#   → grando: NOUN
#   → granum: ADJ
#   → gladius: NOUN
#   → Gallus: ADJ
#   → gradus: NOUN
#   → gazophylacium: NOUN
#   → gredior: NOUN
#   → genuum: ADJ
#   → genimen: NOUN
#   → generatio: NOUN
#   → Glebus: ADJ
#   → genus: NOUN
#   → Gene: NOUN
#   → germen: NOUN
#   → grex: NOUN
#   → Gigae: NOUN
#   → Gyrus: NOUN
#   → gloria: NOUN
#   → Gurges: NOUN
#   → guttur: NOUN
#   → gurgustium: ADJ
#   → gutta: NOUN
#   → gula: NOUN
#   → gaudeo: VERB
#   → gradus: NOUN
#   → grauo: ADJ
#   → geror: NOUN
#   → germino: NOUN
#   → gigneo: ADJ
#   → glorior: NOUN
#   → gusto: VERB
#   → inimicus: ADJ
#   → iniquitas: NOUN
#   → ira: NOUN
#   → Iris: NOUN
#   → hiems: NOUN
#   → imber: NOUN
#   → iter: NOUN
#   → incensum: NOUN
#   → infirmus: ADJ
#   → ignis: NOUN
#   → infernus: ADJ
#   → insula: NOUN
#   → intellectus: NOUN
#   → imago: NOUN
#   → institor: NOUN
#   → Hydria: NOUN
#   → idolum: NOUN
#   → idiota: NOUN
#   → interitus: NOUN
#   → initium: NOUN
#   → Hyssopus: NOUN
#   → inanis: ADJ
#   → hymnus: NOUN
#   → Israel: PROPN
#   → eo: PRON
#   → instantia: NOUN
#   → introitus: NOUN
#   → hircus: NOUN
#   → hinnulus: NOUN
#   → ianua: NOUN
#   → ianitor: NOUN
#   → iaculum: NOUN
#   → Iacinthus: NOUN
#   → iaspis: NOUN
#   → Iacob: PROPN
#   → Ierusalem: ADJ
#   → Iericho: PROPN
#   → ieiunium: NOUN
#   → iecur: NOUN
#   → iota: NOUN
#   → Iordanis: NOUN
#   → Ioseph: PROPN
#   → iustitia: NOUN
#   → Iustus: VERB
#   → iumentum: NOUN
#   → Iuuentus: NOUN
#   → Iubilus: NOUN
#   → Iuuenis: ADJ
#   → iudicium: NOUN
#   → iuncus: ADJ
#   → Iudea: NOUN
#   → Iudas: PROPN
#   → iugum: NOUN
#   → intro: VERB
#   → ingredior: ADJ
#   → inuenio: VERB
#   → immolo: VERB
#   → introeo: PUNCT
#   → immitto: VERB
#   → impono: VERB
#   → infero: VERB
#   → hinnio: NOUN
#   → impleo: VERB
#   → inclino: NOUN
#   → iaceo: VERB
#   → iacto: VERB
#   → iuro: VERB
#   → intra: ADP
#   → inde: ADV
#   → lapis: NOUN
#   → Laqueus: ADJ
#   → lacus: NOUN
#   → labium: NOUN
#   → latus: NOUN
#   → Later: X
#   → lacryma: NOUN
#   → labor: NOUN
#   → lac: NOUN
#   → laquearium: ADJ
#   → Lana: NOUN
#   → latibulum: NOUN
#   → laus: NOUN
#   → Lampas: NOUN
#   → Lamia: ADJ
#   → latitudo: NOUN
#   → latus: NOUN
#   → latro: NOUN
#   → Lauacrum: NOUN
#   → lancea: NOUN
#   → Lactuca: NOUN
#   → Leena: NOUN
#   → Leo: NOUN
#   → lex: NOUN
#   → legatus: VERB
#   → legio: NOUN
#   → Lepra: NOUN
#   → Lecythus: NOUN
#   → leuo: NOUN
#   → Leuis: ADJ
#   → lectus: ADJ
#   → lectulus: ADJ
#   → lignum: NOUN
#   → liber: ADJ
#   → littera: NOUN
#   → lingua: NOUN
#   → Lilius: NOUN
#   → liuor: NOUN
#   → limus: NOUN
#   → liquefacio: VERB
#   → linum: NOUN
#   → ligo: VERB
#   → linteum: NOUN
#   → Libanus: ADJ
#   → locus: NOUN
#   → lotus: NOUN
#   → locusta: NOUN
#   → lorica: NOUN
#   → loquela: NOUN
#   → luna: NOUN
#   → Lucerna: NOUN
#   → lux: NOUN
#   → lumen: NOUN
#   → Lucifer: PROPN
#   → lupus: NOUN
#   → lutum: NOUN
#   → lustrus: NOUN
#   → Luter: NOUN
#   → lucta: VERB
#   → lauo: NOUN
#   → laboro: VERB
#   → lambo: NOUN
#   → laudo: VERB
#   → lapido: NOUN
#   → lacto: VERB
#   → lacto: VERB
#   → Leuare: VERB
#   → lego: VERB
#   → letor: NOUN
#   → ligo: NOUN
#   → licio: NOUN
#   → liquor: NOUN
#   → Liquarius: ADJ
#   → liueo: NOUN
#   → loquio: NOUN
#   → ludo: NOUN
#   → luceo: VERB
#   → mare: NOUN
#   → malus: ADJ
#   → magnus: ADJ
#   → macula: NOUN
#   → magus: ADJ
#   → mater: NOUN
#   → mansio: NOUN
#   → malleus: ADJ
#   → Maceria: NOUN
#   → Maxilla: NOUN
#   → malus: ADJ
#   → manus: NOUN
#   → Mamma: NOUN
#   → Massa: NOUN
#   → Marmor: NOUN
#   → mandragora: NOUN
#   → Malleolus: ADJ
#   → manna: NOUN
#   → maximus: ADJ
#   → magnitudo: NOUN
#   → maiestas: NOUN
#   → Manica: ADJ
#   → Magnus: ADJ
#   → magnificentia: NOUN
#   → Marsupium: NOUN
#   → medicus: NOUN
#   → Medius: ADJ
#   → melis: ADJ
#   → mensura: NOUN
#   → memoria: NOUN
#   → mensa: NOUN
#   → messis: NOUN
#   → mendacium: NOUN
#   → mendax: ADJ
#   → merces: NOUN
#   → mercenarius: ADJ
#   → meretrix: NOUN
#   → memor: NOUN
#   → mens: NOUN
#   → mel: NOUN
#   → mensis: NOUN
#   → meridies: NOUN
#   → mitis: ADJ
#   → militia: NOUN
#   → misericordia: NOUN
#   → milia: NOUN
#   → Myrrha: NOUN
#   → mignus: ADJ
#   → minimus: ADJ
#   → Myrtus: NOUN
#   → minister: NOUN
#   → miles: NOUN
#   → mons: NOUN
#   → mors: NOUN
#   → mortuus: VERB
#   → mola: NOUN
#   → modius: NOUN
#   → modus: NOUN
#   → Monile: ADJ
#   → morsus: NOUN
#   → monstrum: NOUN
#   → morbus: NOUN
#   → motus: NOUN
#   → mortalis: ADJ
#   → mollis: ADJ
#   → modicus: ADJ
#   → mundus: NOUN
#   → murus: NOUN
#   → mulier: NOUN
#   → mutus: ADJ
#   → Mus: NOUN
#   → murenula: ADJ
#   → munus: NOUN
#   → multus: ADJ
#   → muscipula: NOUN
#   → musca: NOUN
#   → mulus: NOUN
#   → manduco: NOUN
#   → maneo: VERB
#   → magnifico: ADJ
#   → macto: VERB
#   → maledico: NOUN
#   → mereor: VERB
#   → Mechari: PUNCT
#   → meto: PROPN
#   → metior: VERB
#   → mitto: VERB
#   → minueo: NOUN
#   → miror: VERB
#   → milito: NOUN
#   → morior: VERB
#   → moueo: VERB
#   → mordeo: VERB
#   → mollio: NOUN
#   → murmuro: ADJ
#   → mutio: NOUN
#   → mano: NOUN
#   → minus: ADV
#   → natura: NOUN
#   → Natales: ADJ
#   → Nauis: NOUN
#   → nasus: NOUN
#   → Nardus: ADJ
#   → Naris: NOUN
#   → nauigium: NOUN
#   → necessitas: NOUN
#   → necessarius: ADJ
#   → Neruus: ADJ
#   → nebula: NOUN
#   → nequitia: NOUN
#   → nidus: NOUN
#   → nix: NOUN
#   → nitrum: NOUN
#   → nihil: PRON
#   → nycticorax: ADJ
#   → niger: ADJ
#   → nomen: NOUN
#   → nox: NOUN
#   → nouaculum: NOUN
#   → nouus: ADJ
#   → numerus: NOUN
#   → nudus: ADJ
#   → nux: NOUN
#   → nuptia: NOUN
#   → nubes: NOUN
#   → nascor: VERB
#   → nato: VERB
#   → nescio: PRON
#   → nego: VERB
#   → nosco: VERB
#   → nollo: NOUN
#   → numero: NOUN
#   → nimis: ADV
#   → nunc: ADV
#   → oculus: NOUN
#   → homo: NOUN
#   → os: NOUN
#   → ,: PUNCT
#   → os: NOUN
#   → os: NOUN
#   → ,: PUNCT
#   → os: NOUN
#   → ouis: NOUN
#   → Ouile: ADJ
#   → osculum: NOUN
#   → opportunitas: NOUN
#   → onus: NOUN
#   → hortus: NOUN
#   → oleum: NOUN
#   → oliua: ADJ
#   → oleaster: NOUN
#   → opus: NOUN
#   → hora: NOUN
#   → olus: NOUN
#   → olla: NOUN
#   → odor: NOUN
#   → honor: NOUN
#   → oriens: VERB
#   → Occasus: NOUN
#   → ostium: NOUN
#   → Onager: NOUN
#   → onocentaurus: VERB
#   → ovum: NOUN
#   → hostia: NOUN
#   → ordo: NOUN
#   → holocaustum: VERB
#   → organum: NOUN
#   → hordeum: NOUN
#   → Orphanus: ADJ
#   → obesus: NOUN
#   → orbis: NOUN
#   → odio: NOUN
#   → occideo: VERB
#   → obturo: PUNCT
#   → oro: VERB
#   → obedio: VERB
#   → operor: VERB
#   → obuio: PUNCT
#   → occurro: VERB
#   → hodie: ADV
#   → panis: NOUN
#   → pater: NOUN
#   → pascuum: NOUN
#   → Pascha: NOUN
#   → Passer: NOUN
#   → paries: NOUN
#   → palma: NOUN
#   → plaustrum: NOUN
#   → palpebris: NOUN
#   → Pannus: ADJ
#   → platea: NOUN
#   → pax: NOUN
#   → planta: NOUN
#   → pars: NOUN
#   → pauper: ADJ
#   → Pastor: NOUN
#   → passio: NOUN
#   → palea: NOUN
#   → planus: ADJ
#   → pactum: VERB
#   → palmes: NOUN
#   → paradisus: NOUN
#   → Platanus: ADJ
#   → psalterium: NOUN
#   → psalmus: NOUN
#   → paruulus: ADJ
#   → pauimentum: NOUN
#   → paliurus: ADJ
#   → pallium: NOUN
#   → Pardus: NOUN
#   → peccatum: NOUN
#   → pes: NOUN
#   → Penna: ADJ
#   → pellis: NOUN
#   → pecus: NOUN
#   → persona: NOUN
#   → perfectus: ADJ
#   → pretiosus: ADJ
#   → preputium: VERB
#   → petra: NOUN
#   → peccato: NOUN
#   → r: X
#   → perdix: NOUN
#   → predestinatio: NOUN
#   → prelium: ADJ
#   → penitentia: NOUN
#   → pecunia: NOUN
#   → pectus: NOUN
#   → pena: NOUN
#   → preco: ADJ
#   → plenus: ADJ
#   → plenitudo: NOUN
#   → presepe: VERB
#   → piscis: NOUN
#   → pix: NOUN
#   → primogenitus: ADJ
#   → pinguis: NOUN
#   → pinguedo: NOUN
#   → Pilus: NOUN
#   → Pleiades: NOUN
#   → princeps: NOUN
#   → principatus: NOUN
#   → principium: NOUN
#   → piger: NOUN
#   → primitie: VERB
#   → primus: ADJ
#   → Pyrgus: NOUN
#   → Pisticus: ADJ
#   → pietas: NOUN
#   → piscina: NOUN
#   → porta: NOUN
#   → potus: NOUN
#   → pomum: NOUN
#   → propheta: NOUN
#   → PROPHETISSA: NOUN
#   → ;: PUNCT
#   → potestas: NOUN
#   → populus: NOUN
#   → poculum: NOUN
#   → profundus: ADJ
#   → proximus: ADJ
#   → proprium: ADJ
#   → puer: NOUN
#   → puteus: NOUN
#   → vluuia: ADJ
#   → plumbum: NOUN
#   → pulex: ADJ
#   → Pruina: NOUN
#   → pugillus: ADJ
#   → pusillus: ADJ
#   → pupillus: NOUN
#   → Pupilla: NOUN
#   → puluis: NOUN
#   → Pruna: NOUN
#   → pulchritudo: NOUN
#   → plumarium: ADJ
#   → putridus: ADJ
#   → putredo: NOUN
#   → multus: ADJ
#   → Pullus: ADJ
#   → putatio: NOUN
#   → pugno: NOUN
#   → pareo: VERB
#   → parturio: VERB
#   → planto: PUNCT
#   → pasco: VERB
#   → pati: VERB
#   → pateo: VERB
#   → parco: NOUN
#   → paro: VERB
#   → peniteo: ADV
#   → pereo: VERB
#   → permitto: VERB
#   → perdo: VERB
#   → percutio: NOUN
#   → posse: VERB
#   → pono: VERB
#   → polluo: NOUN
#   → propheto: NOUN
#   → probo: VERB
#   → procedo: VERB
#   → porto: VERB
#   → poto: NOUN
#   → postulo: VERB
#   → pungo: NOUN
#   → plueo: NOUN
#   → putreo: ADJ
#   → pulso: VERB
#   → purgo: VERB
#   → compositio: NOUN
#   → pre: ADP
#   → pre: ADP
#   → compositio: NOUN
#   → praeter: ADP
#   → propter: ADP
#   → Prope: NOUN
#   → quadrans: VERB
#   → quadriga: NOUN
#   → quadrusuel: VERB
#   → quadro: NOUN
#   → quadruplex: ADJ
#   → qualis: DET
#   → quartus: ADJ
#   → quassatio: NOUN
#   → questio: NOUN
#   → quercus: NOUN
#   → questus: NOUN
#   → quidam: DET
#   → quero: VERB
#   → quasi: ADV
#   → quando: SCONJ
#   → que: CCONJ
#   → quin: SCONJ
#   → quod: SCONJ
#   → ratio: NOUN
#   → radix: NOUN
#   → ramus: ADJ
#   → rapina: NOUN
#   → Rhamnus: NOUN
#   → rana: NOUN
#   → rex: NOUN
#   → regnum: NOUN
#   → reto: NOUN
#   → renis: NOUN
#   → responsum: NOUN
#   → reptilis: ADJ
#   → rectus: VERB
#   → res: NOUN
#   → Regulus: ADJ
#   → regula: NOUN
#   → reliquie: NOUN
#   → riuus: NOUN
#   → rhinoceros: NOUN
#   → rota: NOUN
#   → rosa: NOUN
#   → Ros: NOUN
#   → rupis: NOUN
#   → Rufus: NOUN
#   → rubrus: ADJ
#   → ruina: NOUN
#   → rapio: VERB
#   → regno: NOUN
#   → relinquo: VERB
#   → respico: NOUN
#   → reddo: VERB
#   → reuerto: PUNCT
#   → reminiscor: VERB
#   → repleo: VERB
#   → redimeo: VERB
#   → remitto: VERB
#   → refero: VERB
#   → recedo: VERB
#   → recenseo: ADV
#   → roro: NOUN
#   → rogo: VERB
#   → retro: DET
#   → sapientia: NOUN
#   → Saccus: NOUN
#   → satus: NOUN
#   → sacramentum: NOUN
#   → sacrus: ADJ
#   → sanctus: ADJ
#   → sacrarium: NOUN
#   → sacerdos: NOUN
#   → sacrificium: NOUN
#   → sanitas: NOUN
#   → sacerdotium: NOUN
#   → sal: NOUN
#   → sagitta: NOUN
#   → sabbatum: ADJ
#   → sanguis: NOUN
#   → salus: NOUN
#   → salutaris: ADJ
#   → sagena: NOUN
#   → Scabellus: NOUN
#   → Scandalus: VERB
#   → stabulum: NOUN
#   → scama: ADP
#   → scala: NOUN
#   → stadium: NOUN
#   → Stratus: VERB
#   → statera: NOUN
#   → statura: NOUN
#   → stragulum: NOUN
#   → stagnum: NOUN
#   → saliunca: ADJ
#   → Saliua: NOUN
#   → saxum: NOUN
#   → scapula: NOUN
#   → Sarmentum: NOUN
#   → Sapphirus: NOUN
#   → Sardius: ADJ
#   → Sardonix: NOUN
#   → salix: NOUN
#   → semen: NOUN
#   → Smaragdus: ADJ
#   → sepes: NOUN
#   → seruus: NOUN
#   → sermo: NOUN
#   → sedes: NOUN
#   → sensus: NOUN
#   → senex: ADJ
#   → senectus: NOUN
#   → semita: NOUN
#   → stella: NOUN
#   → sepulcrum: NOUN
#   → SEMIS: NUM
#   → ,: PUNCT
#   → semissum: VERB
#   → sterilis: ADJ
#   → stercus: NOUN
#   → speculum: NOUN
#   → speculum: NOUN
#   → sphera: PUNCT
#   → spelunca: NOUN
#   → spes: NOUN
#   → species: NOUN
#   → securis: NOUN
#   → schema: NOUN
#   → serra: NOUN
#   → serus: NOUN
#   → serpens: VERB
#   → sinus: NOUN
#   → scientia: NOUN
#   → signum: NOUN
#   → similitudo: NOUN
#   → simplex: ADJ
#   → spina: NOUN
#   → spiritus: NOUN
#   → spico: ADJ
#   → spiraculum: NOUN
#   → Sindon: NOUN
#   → situla: NOUN
#   → stillicidium: NOUN
#   → vilua: VERB
#   → signaculum: NOUN
#   → signo: NOUN
#   → stipula: VERB
#   → sinistra: ADJ
#   → Scintilla: NOUN
#   → stirps: NOUN
#   → Sycomorus: NOUN
#   → Silica: ADJ
#   → symbolum: NOUN
#   → Sinapi: NOUN
#   → sitis: VERB
#   → sinceritas: NOUN
#   → sincor: NOUN
#   → synodus: NOUN
#   → Stylus: NOUN
#   → silentium: NOUN
#   → S: NUM
#   → yon: PUNCT
#   → scriba: NOUN
#   → Sol: NOUN
#   → sors: NOUN
#   → soror: NOUN
#   → sopor: NOUN
#   → solitudo: NOUN
#   → solium: NOUN
#   → somnus: NOUN
#   → Scorpius: NOUN
#   → scopa: NOUN
#   → stola: NOUN
#   → Strophea: ADJ
#   → spolium: NOUN
#   → sonus: NOUN
#   → sporta: NOUN
#   → sponsa: VERB
#   → scoria: NOUN
#   → substantia: NOUN
#   → sus: NOUN
#   → sudarium: ADJ
#   → sudor: NOUN
#   → surdus: NOUN
#   → sulcus: NOUN
#   → scutum: NOUN
#   → sulphur: NOUN
#   → Spurius: ADJ
#   → susurrium: NOUN
#   → superliminare: VERB
#   → sublimis: ADJ
#   → scrupulus: NOUN
#   → superbia: NOUN
#   → supercilium: NOUN
#   → subsellium: ADJ
#   → scrutinium: NOUN
#   → Struthius: ADJ
#   → sanctifico: VERB
#   → sacrifico: NOUN
#   → Sanare: VERB
#   → saluo: ADJ
#   → saturo: NOUN
#   → satiao: VERB
#   → sapeo: PUNCT
#   → semino: NOUN
#   → seou: NOUN
#   → sepelo: PUNCT
#   → sedo: PUNCT
#   → sterneresterto: ADV
#   → scribo: VERB
#   → sibilo: NOUN
#   → spiro: VERB
#   → sileo: VERB
#   → sitio: VERB
#   → scio: VERB
#   → sono: NOUN
#   → sto: VERB
#   → soluo: VERB
#   → spolio: NOUN
#   → scrutor: NOUN
#   → suffero: NOUN
#   → supero: NOUN
#   → suscipio: VERB
#   → suscito: VERB
#   → surgo: VERB
#   → subsanno: NOUN
#   → subduco: X
#   → subiicio: NOUN
#   → suppono: VERB
#   → subeo: VERB
#   → sustineo: VERB
#   → supplanto: VERB
#   → suggillo: NOUN
#   → septuplum: VERB
#   → semel: ADV
#   → sero: ADV
#   → simpliciter: ADV
#   → sicut: SCONJ
#   → similiter: ADV
#   → simul: ADV
#   → secundus: ADJ
#   → sino: AUX
#   → vel: SCONJ
#   → supra: ADP
#   → tabernaculum: NOUN
#   → talentum: NOUN
#   → Thalamus: VERB
#   → tabula: NOUN
#   → tabes: NOUN
#   → talis: DET
#   → tantus: ADJ
#   → taxus: NOUN
#   → Taurus: NOUN
#   → transitus: NOUN
#   → trabes: NOUN
#   → Trabea: NOUN
#   → tradux: VERB
#   → templum: NOUN
#   → Testa: NOUN
#   → tectum: NOUN
#   → terra: NOUN
#   → tempus: NOUN
#   → terminus: NOUN
#   → tempestas: NOUN
#   → Theophania: ADJ
#   → Telonius: ADJ
#   → testamentum: NOUN
#   → testimonium: NOUN
#   → Tela: NOUN
#   → testudo: NOUN
#   → terribilis: ADJ
#   → tepidus: ADJ
#   → Tenebre: VERB
#   → tegmen: NOUN
#   → thesaurus: NOUN
#   → tentorium: NOUN
#   → tenuis: ADJ
#   → temperantia: NOUN
#   → tetragrammaton: VERB
#   → tersus: NOUN
#   → tenerus: VERB
#   → Titius: NOUN
#   → Triuius: ADV
#   → triticum: NOUN
#   → Thymiama: NOUN
#   → Tilia: ADJ
#   → titulus: NOUN
#   → tibia: NOUN
#   → tribunal: NOUN
#   → tributum: VERB
#   → tinea: VERB
#   → timor: NOUN
#   → trinitas: NOUN
#   → tres: NUM
#   → Tympanistria: ADJ
#   → tristitia: NOUN
#   → tignum: NOUN
#   → tribulus: NOUN
#   → Triclinium: NOUN
#   → tritura: NOUN
#   → Trieris: NOUN
#   → typus: NOUN
#   → tympanum: NOUN
#   → tribulatio: NOUN
#   → tinum: PUNCT
#   → Tigris: NOUN
#   → torcular: NOUN
#   → tonitrus: NOUN
#   → tonitruum: NOUN
#   → Thorax: NOUN
#   → tonus: NOUN
#   → tropeum: NOUN
#   → Troia: NOUN
#   → tornatilis: ADJ
#   → Topazius: NOUN
#   → tropologia: ADJ
#   → tropus: NOUN
#   → thronus: ADJ
#   → totus: DET
#   → toga: NOUN
#   → tormentum: ADJ
#   → tortor: NOUN
#   → torques: NOUN
#   → torrens: VERB
#   → Torus: NOUN
#   → tunica: NOUN
#   → thus: NOUN
#   → thuribulum: NOUN
#   → tumulus: NOUN
#   → Tugurium: NOUN
#   → tumor: NOUN
#   → turris: NOUN
#   → Tuba: NOUN
#   → turtur: VERB
#   → turbo: NOUN
#   → turba: NOUN
#   → Trulla: NOUN
#   → tutor: NOUN
#   → truncus: NOUN
#   → turpis: ADJ
#   → trado: VERB
#   → transeo: VERB
#   → transfiguro: NOUN
#   → traho: VERB
#   → tabesco: NOUN
#   → tento: VERB
#   → tedo: VERB
#   → thesaurizo: VERB
#   → teneo: VERB
#   → tendeo: VERB
#   → tremo: NOUN
#   → trituro: VERB
#   → triumpho: NOUN
#   → tribuo: VERB
#   → tollo: VERB
#   → tono: NOUN
#   → torreo: ADJ
#   → tumeo: NOUN
#   → trutino: NOUN
#   → turbo: NOUN
#   → tunc: ADV
#   → urbs: NOUN
#   → uter: SCONJ
#   → unguentum: NOUN
#   → uberus: VERB
#   → usura: NOUN
#   → uxor: NOUN
#   → Umbilicus: ADJ
#   → humor: NOUN
#   → humilitas: NOUN
#   → humilis: ADJ
#   → humanitas: NOUN
#   → humanus: ADJ
#   → ulne: NOUN
#   → uterus: NOUN
#   → humerus: NOUN
#   → humus: NOUN
#   → Urtica: NOUN
#   → Usia: NOUN
#   → Usiosi: NOUN
#   → unicus: ADJ
#   → umbra: NOUN
#   → ulmus: NOUN
#   → vua: ADJ
#   → unguis: NOUN
#   → ungula: NOUN
#   → unicornis: NOUN
#   → Ursus: NOUN
#   → ululatus: VERB
#   → uo: X
#   → uanitas: NOUN
#   → uanus: ADJ
#   → uallis: NOUN
#   → uagen: VERB
#   → ualitudo: NOUN
#   → Uacca: NOUN
#   → uapor: NOUN
#   → uastitas: NOUN
#   → ueritas: NOUN
#   → uerus: ADJ
#   → uerax: ADJ
#   → uerecundia: NOUN
#   → uelamen: NOUN
#   → Uenenus: NOUN
#   → Uena: NOUN
#   → uelamentum: NOUN
#   → uermis: ADJ
#   → uermiculus: ADJ
#   → uestimentum: NOUN
#   → uestor: NOUN
#   → uestis: NOUN
#   → uestigium: NOUN
#   → uespa: VERB
#   → uentus: NOUN
#   → uenter: NOUN
#   → uesperus: ADJ
#   → uerbus: NOUN
#   → uentilabrum: NOUN
#   → Uersus: NOUN
#   → uertex: NOUN
#   → Uectis: X
#   → uetus: NOUN
#   → uetustas: NOUN
#   → Uellus: NOUN
#   → uerber: NOUN
#   → uehemens: ADJ
#   → uernaculum: NOUN
#   → vel: CCONJ
#   → vernus: NOUN
#   → uertigo: VERB
#   → uepres: NOUN
#   → uitis: NOUN
#   → Uindemia: ADJ
#   → uinea: NOUN
#   → uinum: NOUN
#   → Uilla: NOUN
#   → Uillicus: NOUN
#   → Uicus: NOUN
#   → uia: NOUN
#   → uiaticum: ADJ
#   → uiator: NOUN
#   → uita: NOUN
#   → uisio: NOUN
#   → Uicinus: ADJ
#   → Uirtus: NOUN
#   → Uir: NOUN
#   → Uirga: NOUN
#   → Uirgus: NOUN
#   → uirginitas: NOUN
#   → uitrum: NOUN
#   → uictoria: NOUN
#   → uinculum: ADJ
#   → Uigilia: NOUN
#   → Uirgultus: VERB
#   → Uitulus: ADJ
#   → uiscus: NOUN
#   → uiscerum: NOUN
#   → uitta: NOUN
#   → Uis: NOUN
#   → uincgo: VERB
#   → vidua: NOUN
#   → uipera: VERB
#   → Uictima: NOUN
#   → uiror: NOUN
#   → Uitula: NOUN
#   → uox: NOUN
#   → uocalis: ADJ
#   → uolutabrum: VERB
#   → Uoluntas: NOUN
#   → uotum: VERB
#   → uomitus: NOUN
#   → Uomer: NOUN
#   → Uolucris: NOUN
#   → uoluptas: NOUN
#   → uultus: NOUN
#   → uulnus: NOUN
#   → Uultur: VERB
#   → uulpes: NOUN
#   → vulua: NOUN
#   → ureo: NOUN
#   → urgeo: VERB
#   → ungo: NOUN
#   → uti: VERB
#   → ululor: NOUN
#   → humilio: ADJ
#   → uadeo: VERB
#   → uaco: NOUN
#   → uacillaris: ADJ
#   → uendeo: VERB
#   → uenundo: NOUN
#   → uenio: VERB
#   → uentilo: NOUN
#   → uolo: VERB
#   → uerto: VERB
#   → uestior: ADJ
#   → uisito: NOUN
#   → uideo: VERB
#   → uiueo: VERB
#   → uiror: NOUN
#   → uindemior: ADJ
#   → uinco: VERB
#   → uigilo: VERB
#   → Uolare: VERB
#   → uoco: VERB
#   → uulnero: NOUN
#   → usque: ADP
#   → usquequo: VERB
#   → ultra: ADP
#   → ueo: NOUN
#   → zelus: NOUN
#   → Zelotes: PROPN
#   → Zeta: PUNCT
#   → Zephyrus: NOUN
#   → Zyma: VERB
#   → Zizania: NOUN
#   → Zona: NOUN
#   → zelo: NOUN
#   → Lagena: VERB
# Сохранено в: ../output/POS/cleaned_alanus_de_insula_dist_summa.predicted_лем_pos_stats.csv
#
# Обработка файла: cleaned_nicolas_de_gorran_distinctiones.predicted_лем.csv
#   → abeo: VERB
#   → assumo: VERB
#   → attendeo: VERB
#   → audio: VERB
#   → abstineo: VERB
#   → ABSCONDERE: NOUN
#   → ,: PUNCT
#   → absconsio: NOUN
#   → amicus: NOUN
#   → deus: NOUN
#   → accipio: VERB
#   → amor: NOUN
#   → ambulo: NOUN
#   → accedo: VERB
#   → adiuvo: PUNCT
#   → amaritudo: NOUN
#   → ago: VERB
#   → arguo: VERB
#   → aqua: NOUN
#   → adoratio: NOUN
#   → armum: NOUN
#   → uirtus: NOUN
#   → apparitio: NOUN
#   → Christus: ADJ
#   → Angustia: NOUN
#   → argentum: NOUN
#   → Ancilla: NOUN
#   → auris: NOUN
#   → acquiro: VERB
#   → aspico: NOUN
#   → accusatio: NOUN
#   → ager: NOUN
#   → agnus: NOUN
#   → deus: NOUN
#   → angelus: NOUN
#   → angelus: NOUN
#   → officium: NOUN
#   → habiceo: ADV
#   → aperio: VERB
#   → ascendo: VERB
#   → anima: NOUN
#   → rationalis: ADJ
#   → auaritia: NOUN
#   → ardor: NOUN
#   → aurum: NOUN
#   → apropinquo: ADJ
#   → aufero: VERB
#   → benefacio: PUNCT
#   → bonus: ADJ
#   → beatitudo: NOUN
#   → benedico: VERB
#   → benignitas: NOUN
#   → deus: NOUN
#   → bonus: ADJ
#   → bello: NOUN
#   → Baculus: NOUN
#   → bonus: ADJ
#   → caritas: NOUN
#   → corona: NOUN
#   → gloria: NOUN
#   → cognosco: VERB
#   → confessio: NOUN
#   → custodio: VERB
#   → consolatio: NOUN
#   → cado: VERB
#   → Cor: NOUN
#   → certamen: ADJ
#   → ,: PUNCT
#   → certo: ADJ
#   → candor: NOUN
#   → claritas: NOUN
#   → CONCUPISCERE: ADJ
#   → ,: PUNCT
#   → concupiscentia: NOUN
#   → ciuitas: NOUN
#   → congregatio: NOUN
#   → capeo: VERB
#   → calix: NOUN
#   → COGITATIO: NOUN
#   → ,: PUNCT
#   → cogito: VERB
#   → cantus: NOUN
#   → celum: ADJ
#   → cupiditas: NOUN
#   → castitas: NOUN
#   → cresco: NOUN
#   → conuiuium: NOUN
#   → carus: VERB
#   → corpus: NOUN
#   → CECUS: NOUN
#   → ,: PUNCT
#   → cecitas: NOUN
#   → cibus: NOUN
#   → credo: VERB
#   → clamo: VERB
#   → certitudo: NOUN
#   → curro: VERB
#   → conuersio: NOUN
#   → considero: VERB
#   → crucifixio: NOUN
#   → crux: NOUN
#   → COLLIGERE: VERB
#   → ,: PUNCT
#   → collectio: NOUN
#   → cena: NOUN
#   → debeo: VERB
#   → detractio: NOUN
#   → Dyabolus: NOUN
#   → disco: NOUN
#   → dico: VERB
#   → viuitie: VERB
#   → dolor: NOUN
#   → DESIDERIUM: NOUN
#   → ,: PUNCT
#   → desidero: VERB
#   → descensus: NOUN
#   → deprecor: VERB
#   → deficio: VERB
#   → Demoniacus: NOUN
#   → dulcedo: NOUN
#   → doceo: VERB
#   → duo: NUM
#   → delicia: NOUN
#   → deus: NOUN
#   → domus: NOUN
#   → Diuisius: ADJ
#   → dilectio: NOUN
#   → deus: NOUN
#   → duco: VERB
#   → dormitio: NOUN
#   → dies: NOUN
#   → delectatio: NOUN
#   → do: VERB
#   → dominus: NOUN
#   → deus: NOUN
#   → dirigo: VERB
#   → erro: NOUN
#   → euangelium: NOUN
#   → egenus: NOUN
#   → ,: PUNCT
#   → egestas: NOUN
#   → elemosina: ADJ
#   → eleuatio: NOUN
#   → exaltatio: NOUN
#   → edificatio: NOUN
#   → extendo: VERB
#   → manus: NOUN
#   → totus: DET
#   → totus: DET
#   → cor: NOUN
#   → Eruditius: VERB
#   → esuries: NOUN
#   → ,: PUNCT
#   → esurio: VERB
#   → eicio: VERB
#   → deus: NOUN
#   → reprobus: ADJ
#   → IUSTE: ADV
#   → ,: PUNCT
#   → eicio: VERB
#   → iustus: ADJ
#   → malus: ADJ
#   → caute: ADV
#   → exaudio: VERB
#   → exultatio: NOUN
#   → eternitas: NOUN
#   → epulatio: NOUN
#   → expectatio: NOUN
#   → equitas: NOUN
#   → eloquium: ADJ
#   → ebrietas: NOUN
#   → emptio: NOUN
#   → electio: NOUN
#   → egressus: VERB
#   → exitus: NOUN
#   → filius: NOUN
#   → homo: NOUN
#   → fornicatio: NOUN
#   → fluctus: NOUN
#   → FLERE: VERB
#   → ,: PUNCT
#   → PLORARE: VERB
#   → ,: PUNCT
#   → lacrimo: NOUN
#   → facilitas: NOUN
#   → forma: NOUN
#   → fraternitas: NOUN
#   → fidelitas: NOUN
#   → filiatio: NOUN
#   → deus: NOUN
#   → fortitudo: NOUN
#   → facio: VERB
#   → finis: NOUN
#   → flos: NOUN
#   → ,: PUNCT
#   → flos: NOUN
#   → fons: NOUN
#   → fructus: NOUN
#   → fugio: VERB
#   → fides: NOUN
#   → generatio: NOUN
#   → gens: NOUN
#   → ,: PUNCT
#   → gens: NOUN
#   → gustus: NOUN
#   → GEMERE: VERB
#   → ,: PUNCT
#   → gemitus: NOUN
#   → gladius: NOUN
#   → gratia: NOUN
#   → gloria: NOUN
#   → gaudium: NOUN
#   → habeo: VERB
#   → homo: NOUN
#   → hereditas: NOUN
#   → Ihesus: PROPN
#   → Christus: ADJ
#   → filius: NOUN
#   → deus: NOUN
#   → HABUNDARE: NOUN
#   → ,: PUNCT
#   → abundantia: NOUN
#   → habitatio: NOUN
#   → hora: NOUN
#   → honestas: NOUN
#   → honoro: NOUN
#   → humilitas: NOUN
#   → Ihesus: PROPN
#   → nomen: NOUN
#   → eo: PRON
#   → inclinatio: NOUN
#   → infirmitas: NOUN
#   → ira: NOUN
#   → ignis: NOUN
#   → inimicus: ADJ
#   → iudicium: NOUN
#   → induo: ADP
#   → ignorantia: NOUN
#   → Inuicem: PRON
#   → iugum: NOUN
#   → illuminare: VERB
#   → ,: PUNCT
#   → lumen: NOUN
#   → innocentia: NOUN
#   → inuidia: NOUN
#   → intro: VERB
#   → inquisitio: NOUN
#   → iocunditas: NOUN
#   → imitor: VERB
#   → intelligo: VERB
#   → intellectus: NOUN
#   → iustitia: NOUN
#   → Iustus: VERB
#   → iustus: ADJ
#   → Christus: ADJ
#   → ieiunium: NOUN
#   → LUGERE: VERB
#   → ,: PUNCT
#   → luctus: NOUN
#   → Laqueus: NOUN
#   → lux: NOUN
#   → lumen: NOUN
#   → lex: NOUN
#   → deus: NOUN
#   → lingua: NOUN
#   → /: PUNCT
# ...
#   → cupiditas: NOUN
#   → curo: VERB
#   → curuatio: NOUN
#   → cubilis: ADJ
#   → currus: NOUN
#   → custodio: VERB
#   → d: X
#   → dampnum: ADJ
#   → dampnatio: NOUN
#   → do: VERB
#   → debilitas: NOUN
#   → debitum: VERB
#   → deceptio: NOUN
#   → decor: NOUN
#   → declino: ADJ
#   → dedicatio: NOUN
#   → deduco: NOUN
#   → defectus: NOUN
#   → defensio: NOUN
#   → deiectio: NOUN
#   → deletio: NOUN
#   → delectatio: NOUN
#   → delicie: VERB
#   → delictum: VERB
#   → Demolitius: ADV
#   → demonstratio: NOUN
#   → demonium: NOUN
#   → dens: NOUN
#   → denudatio: NOUN
#   → depositum: VERB
#   → deprecatio: NOUN
#   → depressio: NOUN
#   → derelictio: NOUN
#   → derisio: NOUN
#   → descriptio: NOUN
#   → descendo: VERB
#   → desertum: NOUN
#   → desiderabilis: ADJ
#   → desiderium: NOUN
#   → desolatio: NOUN
#   → despectio: NOUN
#   → desperatio: NOUN
#   → desponsatio: NOUN
#   → destructio: NOUN
#   → detentio: NOUN
#   → detestatio: NOUN
#   → detractio: NOUN
#   → deuoratio: NOUN
#   → dextera: ADJ
#   → diadema: NOUN
#   → dies: NOUN
#   → dilatio: NOUN
#   → digitus: ADJ
#   → dignitas: NOUN
#   → differentia: NOUN
#   → diffusio: NOUN
#   → dilatatio: NOUN
#   → dilectio: NOUN
#   → diligentia: NOUN
#   → diluculum: NOUN
#   → diluuium: ADJ
#   → dissolutio: NOUN
#   → directio: NOUN
#   → dimissio: NOUN
#   → disciplina: NOUN
#   → discipulus: NOUN
#   → diruptio: NOUN
#   → discessio: NOUN
#   → disceptatio: NOUN
#   → discum: NOUN
#   → bo: NUM
#   → discursus: NOUN
#   → dispensatio: NOUN
#   → dispositio: NOUN
#   → dispersio: NOUN
#   → dissipo: NOUN
#   → viuitie: NOUN
#   → diuersio: NOUN
#   → diuersitas: NOUN
#   → Diuisius: ADV
#   → doctrina: NOUN
#   → doceo: VERB
#   → dolus: NOUN
#   → dolor: NOUN
#   → dominium: NOUN
#   → domus: NOUN
#   → donum: NOUN
#   → dormitio: NOUN
#   → dormitatio: NOUN
#   → duco: VERB
#   → duplicitas: NOUN
#   → dulcedo: NOUN
#   → duritia: NOUN
#   → e: ADP
#   → ebrietas: NOUN
#   → Ebur: NOUN
#   → ecce: PART
#   → edificatio: NOUN
#   → educo: NOUN
#   → effusio: NOUN
#   → egestas: NOUN
#   → egredior: VERB
#   → eiectio: NOUN
#   → Eleuatio: NOUN
#   → electio: NOUN
#   → eloquium: ADJ
#   → emptio: NOUN
#   → emissio: NOUN
#   → emundatio: NOUN
#   → emulatio: NOUN
#   → enarratio: NOUN
#   → epula: ADJ
#   → equitas: NOUN
#   → eradicatio: NOUN
#   → Ereptius: ADJ
#   → eripio: VERB
#   → error: NOUN
#   → erubescentia: VERB
#   → Eruditius: VERB
#   → eruo: VERB
#   → erumpo: PUNCT
#   → esca: NOUN
#   → esto: AUX
#   → estus: NOUN
#   → estimatio: NOUN
#   → esurio: NOUN
#   → euacuatio: NOUN
#   → euulsio: NOUN
#   → euentus: NOUN
#   → euersio: NOUN
#   → euigilatio: NOUN
#   → exaltatio: NOUN
#   → exaudio: VERB
#   → excessus: NOUN
#   → excelsus: VERB
#   → excisio: NOUN
#   → excitatio: NOUN
#   → excussio: NOUN
#   → exemplum: NOUN
#   → excercitium: VERB
#   → exhibitio: NOUN
#   → exhortatio: NOUN
#   → exitus: NOUN
#   → expando: ADJ
#   → expulsio: NOUN
#   → expugnatio: NOUN
#   → exquisitio: NOUN
#   → expoliatio: NOUN
#   → expectatio: NOUN
#   → exsurgo: NOUN
#   → extensio: NOUN
#   → exterminatio: NOUN
#   → extinguo: NOUN
#   → exultatio: NOUN
#   → f: X
#   → fabricatio: NOUN
#   → facio: VERB
#   → facio: VERB
#   → fallacia: NOUN
#   → falsitas: NOUN
#   → fames: NOUN
#   → fasciculus: ADJ
#   → fatigatio: NOUN
#   → Fauus: ADJ
#   → fedus: NOUN
#   → femur: NOUN
#   → feneratio: NOUN
#   → fenus: NOUN
#   → fenestra: NOUN
#   → ferocitas: NOUN
#   → fermentum: ADJ
#   → ferrum: NOUN
#   → fero: VERB
#   → feruor: NOUN
#   → festiuitas: NOUN
#   → festinatio: NOUN
#   → fictio: NOUN
#   → fides: NOUN
#   → fidelitas: NOUN
#   → fiducia: NOUN
#   → filius: NOUN
#   → filia: NOUN
#   → finis: NOUN
#   → firmamentum: NOUN
#   → firmitas: NOUN
#   → flagellum: NOUN
#   → flamma: NOUN
#   → flatus: NOUN
#   → flecto: VERB
#   → fletus: NOUN
#   → flos: NOUN
#   → fluctus: NOUN
#   → fluo: ADJ
#   → flumen: NOUN
#   → Fluuius: ADJ
#   → folium: NOUN
#   → fons: NOUN
#   → fornax: ADJ
#   → fornicatio: NOUN
#   → for: PUNCT
#   → formo: NOUN
#   → fortitudo: NOUN
#   → foramen: NOUN
#   → formido: NOUN
#   → vouea: VERB
#   → frango: VERB
#   → fraternitas: NOUN
#   → fraus: NOUN
#   → fremitus: NOUN
#   → frenum: ADJ
#   → frequentia: NOUN
#   → frigus: NOUN
#   → frondis: NOUN
#   → frons: NOUN
#   → fructus: NOUN
#   → fructificatio: NOUN
#   → frugis: NOUN
#   → frumentum: NOUN
#   → fuga: NOUN
#   → fugatio: NOUN
#   → fulgor: NOUN
#   → fulgur: NOUN
#   → fumus: NOUN
#   → funda: NOUN
#   → fundamentum: NOUN
#   → fundatio: NOUN
#   → furor: NOUN
#   → furtum: NOUN
#   → funiculus: NOUN
#   → g: X
#   → Galea: NOUN
#   → gaudium: NOUN
#   → gemma: NOUN
#   → gemitus: NOUN
#   → generatio: NOUN
#   → gens: NOUN
#   → genus: NOUN
#   → germen: NOUN
#   → germino: NOUN
#   → Gigae: NOUN
#   → Gyrus: NOUN
#   → gladius: NOUN
#   → glorificatio: NOUN
#   → gloria: NOUN
#   → gratia: NOUN
#   → gradus: NOUN
#   → gradus: NOUN
#   → grauitas: NOUN
#   → gredior: NOUN
#   → grex: NOUN
#   → gubernaculum: NOUN
#   → gustus: NOUN
#   → guttur: NOUN
#   → h: X
#   → habeo: VERB
#   → habitus: NOUN
#   → habitaculum: NOUN
#   → habitatio: NOUN
#   → habundantia: VERB
#   → Harena: NOUN
#   → Haustus: NOUN
#   → Herba: NOUN
#   → hereditas: NOUN
#   → hesitatio: NOUN
#   → hyems: NOUN
#   → hylaritas: NOUN
#   → Homicidius: ADJ
#   → honestas: NOUN
#   → honor: NOUN
#   → honorificatio: NOUN
#   → honus: NOUN
#   → horreus: ADJ
#   → horror: NOUN
#   → hospitalitas: NOUN
#   → hostia: NOUN
#   → Hostius: ADJ
#   → humilitas: NOUN
#   → humerus: NOUN
#   → humus: NOUN
#   → i: NUM
#   → iaceo: VERB
#   → iacto: VERB
#   → iacto: VERB
#   → iaculum: NOUN
#   → ianua: NOUN
#   → Ydria: ADJ
#   → Ieiunia: NOUN
#   → ignis: NOUN
#   → ignobilitas: NOUN
#   → ignominia: NOUN
#   → ignorantia: NOUN
#   → illusio: NOUN
#   → illuminatio: NOUN
#   → Ymagus: NOUN
#   → imber: NOUN
#   → imitatio: NOUN
#   → imbecillitas: NOUN
#   → immaculatio: NOUN
#   → immolatio: NOUN
#   → immundicia: ADJ
#   → infirmitas: NOUN
#   → impedio: ADJ
#   → imperium: NOUN
#   → impietas: NOUN
#   → impetus: NOUN
#   → impingatio: NOUN
#   → impositio: NOUN
#   → impletio: NOUN
#   → improperium: ADJ
#   → incessus: NOUN
#   → incuruatio: NOUN
#   → inclinatio: NOUN
#   → innocentia: NOUN
#   → increpatio: NOUN
#   → indicatio: NOUN
#   → indigentia: NOUN
#   → inductio: NOUN
#   → induitio: NOUN
#   → inebriatio: NOUN
#   → infidelitas: NOUN
#   → inflatio: NOUN
#   → inflammatio: NOUN
#   → ingredior: ADJ
#   → iniuria: ADJ
#   → innouatio: NOUN
#   → inopia: NOUN
#   → insania: NOUN
#   → insidiatio: NOUN
#   → insipientia: NOUN
#   → inquisitio: NOUN
#   → insurgo: PUNCT
#   → inspiratio: NOUN
#   → inspico: NOUN
#   → instancia: NOUN
#   → instruo: NOUN
#   → intellectus: NOUN
#   → intelligo: VERB
#   → intendo: VERB
#   → interitus: NOUN
#   → interfectio: NOUN
#   → intueor: VERB
#   → intro: VERB
#   → introductio: NOUN
#   → introeo: DET
#   → inundatio: NOUN
#   → inuentio: NOUN
#   → iniusticia: ADJ
#   → Inuicem: PRON
#   → inquinamentum: NOUN
#   → iniquitas: NOUN
#   → incendium: NOUN
#   → inuidia: NOUN
#   → inuestigatio: NOUN
#   → inuocatio: NOUN
#   → iocunditas: NOUN
#   → ypocrisis: NOUN
#   → irritatio: NOUN
#   → irruitio: NOUN
#   → eo: PRON
#   → irrigatio: NOUN
#   → irrisio: NOUN
#   → ira: NOUN
#   → iungo: VERB
#   → iurgium: NOUN
#   → iustificatio: NOUN
#   → Iubilus: ADJ
#   → iustitia: NOUN
#   → iudicium: NOUN
#   → iuramentum: NOUN
#   → iugum: NOUN
#   → l: X
#   → labium: NOUN
#   → labor: NOUN
#   → lac: NOUN
#   → lacus: NOUN
#   → laceratio: NOUN
#   → lacrima: NOUN
#   → lamentum: NOUN
#   → Lampas: NOUN
#   → lango: PUNCT
#   → lapsus: VERB
#   → lapis: NOUN
#   → Laqueus: ADJ
#   → latitudo: NOUN
#   → latro: NOUN
#   → lauo: NOUN
#   → laus: NOUN
#   → lectus: ADJ
#   → Leo: NOUN
#   → Lepra: NOUN
#   → Lesius: ADJ
#   → letitia: NOUN
#   → leuatio: NOUN
#   → lex: NOUN
#   → liber: ADJ
#   → libertas: NOUN
#   → libero: ADJ
#   → ligatio: NOUN
#   → lignum: NOUN
#   → Lilius: NOUN
#   → lingua: NOUN
#   → liquefactio: NOUN
#   → litigatio: NOUN
#   → longe: ADV
#   → loquio: ADJ
#   → lorica: NOUN
#   → lubricum: ADJ
#   → Lucerna: NOUN
#   → luctus: NOUN
#   → ludo: NOUN
#   → lumen: NOUN
#   → lumbus: NOUN
#   → luna: NOUN
#   → lustratio: NOUN
#   → lutum: NOUN
#   → lux: NOUN
#   → luxuria: NOUN
#   → M: ADP
#   → macula: NOUN
#   → magnificatio: NOUN
#   → magnitudo: NOUN
#   → malus: ADJ
#   → malicia: ADJ
#   → mansuetudo: NOUN
#   → manducatio: NOUN
#   → manus: NOUN
#   → manifestatio: NOUN
#   → maneo: VERB
#   → mano: PUNCT
#   → mandatum: VERB
#   → mare: NOUN
#   → Medela: NOUN
#   → medicus: NOUN
#   → medius: ADJ
#   → meditatio: NOUN
#   → mel: NOUN
#   → memoria: NOUN
#   → mendacium: NOUN
#   → mendicitas: NOUN
#   → mensura: NOUN
#   → mensa: NOUN
#   → merces: NOUN
#   → meritum: VERB
#   → meretrix: NOUN
#   → meror: NOUN
#   → meridies: NOUN
#   → messis: NOUN
#   → metueo: ADJ
#   → milicia: ADJ
#   → ministratio: NOUN
#   → minoratio: NOUN
#   → miseria: NOUN
#   → misericordia: NOUN
#   → mitto: VERB
#   → mitto: VERB
#   → Mitigatius: VERB
#   → modestia: NOUN
#   → modicus: ADJ
#   → molestia: NOUN
#   → mons: NOUN
#   → mortificatio: NOUN
#   → morsus: NOUN
#   → mora: ADJ
#   → mors: NOUN
#   → multiplicatio: NOUN
#   → mulier: NOUN
#   → mundatio: NOUN
#   → mundus: NOUN
#   → munitio: NOUN
#   → munus: NOUN
#   → murmur: VERB
#   → mutatio: NOUN
#   → mutitas: NOUN
#   → n: NOUN
#   → narratio: NOUN
#   → natiuitas: NOUN
#   → nauicula: ADJ
#   → nebula: NOUN
#   → necessitas: NOUN
#   → negligentia: NOUN
#   → negotiatio: NOUN
#   → nequitia: NOUN
#   → nidus: NOUN
#   → nocumentum: NOUN
#   → nomen: NOUN
#   → vouus: NOUN
#   → notitia: NOUN
#   → nouissimus: ADJ
#   → nox: NOUN
#   → nubes: NOUN
#   → nuditas: NOUN
#   → nuntius: ADJ
#   → nummus: NOUN
#   → nuptia: ADJ
#   → nutrix: NOUN
#   → obedientia: VERB
#   → oblatio: NOUN
#   → obliuio: NOUN
#   → obsidio: NOUN
#   → obuiatio: NOUN
#   → obumbratio: NOUN
#   → oblectamentum: NOUN
#   → obsecratio: NOUN
#   → obseruatio: NOUN
#   → obsequium: NOUN
#   → occisio: NOUN
#   → occursus: NOUN
#   → occultus: VERB
#   → otium: NOUN
#   → occupatio: NOUN
#   → oculus: NOUN
#   → odor: NOUN
#   → odium: NOUN
#   → offensio: NOUN
#   → oleum: NOUN
#   → oliua: ADJ
#   → optimitas: ADJ
#   → operatio: NOUN
#   → opes: NOUN
#   → oppressio: NOUN
#   → opprobrium: NOUN
#   → opportunitas: NOUN
#   → operatio: NOUN
#   → ordinatio: NOUN
#   → Orirus: NOUN
#   → ortus: NOUN
#   → ornatus: NOUN
#   → oriens: VERB
#   → oratio: NOUN
#   → ossum: ADJ
#   → ostensio: NOUN
#   → os: NOUN
#   → ouis: NOUN
#   → p: NUM
#   → pacificatio: NOUN
#   → pax: NOUN
#   → patientia: NOUN
#   → paratio: NOUN
#   → Pastor: NOUN
#   → pastus: NOUN
#   → pascuum: ADJ
#   → paruulus: ADJ
#   → panis: NOUN
#   → paralisis: ADJ
#   → patibulum: NOUN
#   → paupertas: NOUN
#   → pactum: VERB
#   → palpatio: NOUN
#   → paradisus: NOUN
#   → parco: ADJ
#   → partus: NOUN
#   → paries: NOUN
#   → participatio: NOUN
#   → pater: NOUN
#   → pauor: NOUN
#   → pallium: NOUN
#   → perdo: VERB
#   → Peregrinus: ADJ
#   → peccatum: NOUN
#   → penitentia: NOUN
#   → Pellis###: NOUN
#   → #: X
#   → perfectio: NOUN
#   → pena: NOUN
#   → petitio: NOUN
#   → permaneo: VERB
#   → percussio: NOUN
#   → penetratio: NOUN
#   → perductio: NOUN
#   → persecutio: NOUN
#   → perturbatio: NOUN
#   → pes: NOUN
#   → perseuerantia: NOUN
#   → peruersitas: NOUN
#   → pestilentia: NOUN
#   → Pharetra: NOUN
#   → pinguedo: NOUN
#   → pigritia: NOUN
#   → piscatio: NOUN
#   → pietas: NOUN
#   → placo: PUNCT
#   → Plausus: NOUN
#   → placeo: VERB
#   → planctus: NOUN
#   → plenitudo: NOUN
#   → ploro: NOUN
#   → Plantatio###: ADJ
#   → #: X
#   → vluuia: ADJ
#   → porta: NOUN
#   → postulatio: NOUN
#   → Pollutius: VERB
#   → pono: VERB
#   → pondus: NOUN
#   → porrigo: VERB
#   → porto: VERB
#   → possessio: NOUN
#   → potus: NOUN
#   → positio: NOUN
#   → pretium: NOUN
#   → Preesse: VERB
#   → propheta: NOUN
#   → prudentia: NOUN
#   → preparatio: NOUN
#   → probatio: NOUN
#   → prouidentia: NOUN
#   → promissio: NOUN
#   → proiectio: NOUN
#   → propitiatio: NOUN
#   → precingor: NOUN
#   → Prope: PUNCT
#   → protectio: NOUN
#   → primitie: NOUN
#   → precipio: VERB
#   → principatus: NOUN
#   → prex: NOUN
#   → prauitas: NOUN
#   → prebero: NOUN
#   → praecedo: VERB
#   → precido: NOUN
#   → precipitatio: NOUN
#   → prelium: ADJ
#   → presbyter: NOUN
#   → produco: VERB
#   → profunditas: NOUN
#   → prolongatio: NOUN
#   → preparo: VERB
#   → proficio: NOUN
#   → pugno: NOUN
#   → puteus: NOUN
#   → pulcritudo: NOUN
#   → puer: NOUN
#   → purgatio: NOUN
#   → purificatio: NOUN
#   → puritas: NOUN
#   → q quadrigesimus: VERB
#   → quero: VERB
#   → Querela: NOUN
#   → quiesco: NOUN
#   → r: X
#   → radix: NOUN
#   → rapina: NOUN
#   → rebellio: NOUN
#   → rectitudo: NOUN
#   → rector: NOUN
#   → recubitus: VERB
#   → recessus: NOUN
#   → recipio: VERB
#   → reclinatio: NOUN
#   → recogitatio: NOUN
#   → reconciliatio: NOUN
#   → recordatio: NOUN
#   → reddo: VERB
#   → redimeo: NOUN
#   → redargutio: NOUN
#   → reductio: NOUN
#   → refectio: NOUN
#   → refrigerium: ADJ
#   → refugium: NOUN
#   → regimen: NOUN
#   → regnum: NOUN
#   → regno: NOUN
#   → regressus: VERB
#   → regula: NOUN
#   → reliquie: NOUN
#   → religio: NOUN
#   → relictio: NOUN
#   → remissio: NOUN
#   → remitto: VERB
#   → renouatio: NOUN
#   → repletio: NOUN
#   → repello: VERB
#   → repositio: NOUN
#   → reportatio: NOUN
#   → reprehensio: NOUN
#   → reprobatio: NOUN
#   → repugnatio: NOUN
#   → requies: NOUN
#   → requisitio: NOUN
#   → resurrectio: NOUN
#   → respectus: NOUN
#   → reseruatio: NOUN
#   → restitutio: NOUN
#   → Rethe: PUNCT
#   → retentio: NOUN
#   → retributio: NOUN
#   → reuelatio: NOUN
#   → reuersio: NOUN
#   → reuerentia: NOUN
#   → rex: NOUN
#   → rigatio: NOUN
#   → rideo: VERB
#   → roboratio: NOUN
#   → Ros: NOUN
#   → rubor: NOUN
#   → rugitus: NOUN
#   → ruina: NOUN
#   → s: NUM
#   → sacietas: NOUN
#   → sacrificium: NOUN
#   → Saccus: NOUN
#   → sanctificatio: NOUN
#   → sacerdos: NOUN
#   → sanctitas: NOUN
#   → sagitta: NOUN
#   → sagena: NOUN
#   → sal: NOUN
#   → saluo: ADJ
#   → sanatio: NOUN
#   → sanguis: NOUN
#   → sapeo: PUNCT
#   → sapientia: NOUN
#   → saturitas: NOUN
#   → secretum: VERB
#   → securitas: NOUN
#   → seduceo: VERB
#   → sedo: PUNCT
#   → semen: NOUN
#   → sentio: VERB
#   → separatio: NOUN
#   → sepulcrum: NOUN
#   → seou: PUNCT
#   → seruitus: NOUN
#   → seruo: NOUN
#   → signum: NOUN
#   → silentium: NOUN
#   → simulatio: NOUN
#   → simplicitas: NOUN
#   → sinus: NOUN
#   → sitis: NOUN
#   → sobrietas: NOUN
#   → societas: NOUN
#   → Sol: NOUN
#   → soluo: VERB
#   → solacium: NOUN
#   → sollicitudo: NOUN
#   → Sompnus: NOUN
#   → sonus: NOUN
#   → sopor: NOUN
#   → sors: NOUN
#   → subiectio: NOUN
#   → substantia: NOUN
#   → sublimitas: NOUN
#   → Suauitas: NOUN
#   → subleuo: ADJ
#   → subuersio: NOUN
#   → succingo: NOUN
#   → sufficientia: NOUN
#   → sufferentia: VERB
#   → superbia: NOUN
#   → superatio: NOUN
#   → surgo: VERB
#   → sustentatio: NOUN
#   → sustinentia: VERB
#   → suscipio: VERB
#   → suspensio: NOUN
#   → suscitatio: NOUN
#   → suspitio: NOUN
#   → suspirium: ADJ
#   → Scandalus: VERB
#   → scientia: NOUN
#   → scindo: ADJ
#   → scriptura: NOUN
#   → scrutinium: NOUN
#   → scutum: VERB
#   → spacium: NOUN
#   → spes: NOUN
#   → speculatio: NOUN
#   → speciositas: NOUN
#   → splendor: NOUN
#   → spiritus: NOUN
#   → spina: NOUN
#   → spoliatio: NOUN
#   → statera: ADJ
#   → status: NOUN
#   → stabilitas: NOUN
#   → stella: NOUN
#   → studium: NOUN
#   → stulticia: ADJ
#   → t: X
#   → tabernaculum: NOUN
#   → tabesco: NOUN
#   → taceo: VERB
#   → tactus: NOUN
#   → talentum: NOUN
#   → tarditas: NOUN
#   → Taurus: NOUN
#   → tedium: ADJ
#   → tegimen: NOUN
#   → tempestas: NOUN
#   → temptatio: NOUN
#   → Tenebre: VERB
#   → teneo: VERB
#   → terra: NOUN
#   → terror: NOUN
#   → thesaurus: NOUN
#   → timor: NOUN
#   → tormentum: ADJ
#   → torrens: VERB
#   → tunica: NOUN
#   → turpitudo: NOUN
#   → turris: NOUN
#   → turbatio: NOUN
#   → translatio: NOUN
#   → transitus: NOUN
#   → tractatio: NOUN
#   → traho: VERB
#   → transgressio: NOUN
#   → tremor: NOUN
#   → tristitia: NOUN
#   → tribulatio: NOUN
#   → tribuo: VERB
#   → trinitas: NOUN
#   → triticum: ADJ
#   → tronus: NOUN
#   → u: NUM
#   → uacatio: NOUN
#   → Uagatio: NOUN
#   → Uallare: VERB
#   → ualiditas: NOUN
#   → uanitas: NOUN
#   → uo: NOUN
#   → uentus: NOUN
#   → uenio: VERB
#   → uenatio: NOUN
#   → uenditio: NOUN
#   → uenter: NOUN
#   → uelamentum: NOUN
#   → uelocitas: NOUN
#   → ueo: PUNCT
#   → uerberatio: NOUN
#   → uerecundia: NOUN
#   → uermis: ADJ
#   → ueritas: NOUN
#   → Uersius: ADJ
#   → uestigium: NOUN
#   → uestis: NOUN
#   → uexatio: NOUN
#   → uia: NOUN
#   → uictoria: NOUN
#   → uideo: VERB
#   → uigilo: NOUN
#   → uindicta: NOUN
#   → uinum: NOUN
#   → uinea: ADJ
#   → uiolor: PUNCT
#   → uirginitas: NOUN
#   → Uirtus: NOUN
#   → uinculum: ADJ
#   → Uirga: NOUN
#   → uiror: NOUN
#   → uirilitas: NOUN
#   → uita: NOUN
#   → uitis: NOUN
#   → uisitatio: NOUN
#   → uiuificatio: NOUN
#   → uocatio: NOUN
#   → Uoluntas: NOUN
#   → Uolare: VERB
#   → uoluptas: NOUN
#   → uulnus: NOUN
#   → uberus: NOUN
#   → ubertas: NOUN
#   → unguentum: NOUN
#   → unitas: NOUN
#   → utilitas: NOUN
#   → z: X
#   → zelus: NOUN
#   → Zona: NOUN
# Сохранено в: ../output/POS/cleaned_mauritius_hibernicus_distinctiones.predicted_лем_pos_stats.csv
